# %% [markdown]
# ## Needed Imports

# %%
import json
import numpy as np  # Algebra library
import tensorflow as tf  # Tensorflow
import h5py
import matplotlib.pyplot as plt
from scipy.ndimage import zoom

# %% [markdown]
# ## Define Parameters
# Specify the path of the test data and the parameters used for training to load the correct model
#
# ### data.json format:
# {
#     "input_size": [
#         X,
#         Y,
#         Channels
#     ],
#     "num_classes": Number Of Classes,
#     "class_names": [
#         "Class 1",
#         "Class 2"
#     ]
# }

# %%
# Hardcoded values for training parameters
# Path to .5 file for test data
test_data = r"C:\Users\Michael\Desktop\Model Benchmark\data\CatOrDog\test.h5"

# Set this to none if you will manually input the needed variables
dataJson = r"C:\Users\Michael\Desktop\Model Benchmark\data\CatOrDog\data.json"

checkpoint_path = r"C:\Users\Michael\Desktop\Model Benchmark\tensorboard\Models\CatOrDogStandard16_lr0.0001/my_capsule_network"

# Folder Name Of The Saved Model
# folder_name = "CatOrDogStandard"

# Image dimensions that the model was trained on
# Manually Set This If data.json does not exist, otherwise can leave as None
# input_dimensions = [96, 96, 1]
input_dimensions = None

# Class Names
# Manually Set This If data.json does not exist, otherwise can leave as None
# class_names = ["Cat", "Dog"]
class_names = None

# Number of classes
# Manually Set This If data.json does not exist, otherwise can leave as None
# num_classes = 2
num_classes = None

# Automatically read the input_dimensions, class_names and num_classes from a data.json if it exists
if dataJson is not None:
    with open(dataJson, "r") as f:
        data = json.load(f)

    input_dimensions = data['input_size']
    class_names = data['class_names']
    num_classes = data['num_classes']

    f.close()

# # Batch Size The Model Was Trained With
# batch_size = 16
# 
# # How Many Epochs The Model Was Trained With
# # n_epochs = 20
# 
# # Learning Rate The Model Was Trained With
# lr = 0.0001
# 
# # Load model and tensorboard data to this folder
# folder = folder_name + str(batch_size) + "_lr" + str(lr)
# checkpoint_path = "./tensorboard/Models/" + folder + "/my_capsule_network"
# #learning_rate = learning_rate1

# %% [markdown]
# ## Load Test Data
# This can also be replaced with validation data, there just needs to be corresponding labels

# %%
def load_data(path):
    with h5py.File(path, 'r') as f:
        x = f['image'][()]
        y = f['label'][()]
    return np.array(x), np.array(y)


x_test, y_test = load_data(test_data)

# Normalize the image since we don't pass in normalized data but if the data is already normalized we can remove the / 255.
x_test = x_test.reshape((-1, input_dimensions[0], input_dimensions[1], input_dimensions[2])).astype('float32') / 255.
y_test = y_test.astype('float32')

# %% [markdown]
# ## Loading the Model
# The Cell Directly Below Is Template Code That Doesn't Need To Change
#
# The Cell Below This One Can Be Modified To Use The Right Architecture

# %%
def predictions(caps_Lminus1, dims_Lminus1, output_Lminus1,
                caps_L, dims_L, batch_size, weight_sharing=False, grid_cells_Lminus1=1, name=None):
    with tf.name_scope(name, default_name="predictions"):
        if weight_sharing == False:
            output_Lminus1 = tf.squeeze(output_Lminus1, axis=[1, 4], name="output_Lminus1")

        init_sigma = 0.1
        W_init = tf.random_normal(shape=(1, caps_Lminus1, caps_L, dims_L, dims_Lminus1),
                                  stddev=init_sigma, dtype=tf.float32, name="W_init")
        W = tf.Variable(W_init, name="W")
        tf.summary.histogram("W", W)

        W_tiled = tf.tile(W, [batch_size, grid_cells_Lminus1, 1, 1, 1], name="W_tiled")
        output_expanded_Lminus1 = tf.expand_dims(output_Lminus1, -1, name="output_expanded_Lminus1")
        output_tile_Lminus1 = tf.expand_dims(output_expanded_Lminus1, 2, name="output_tile_Lminus1")
        output_tiled_Lminus1 = tf.tile(output_tile_Lminus1, [1, 1, caps_L, 1, 1], name="output_tiled_Lminus1")
        predicted_L = tf.matmul(W_tiled, output_tiled_Lminus1, name="predicted_L")

        return predicted_L


def routing(caps_Lminus1, caps_L, batch_size, iterations, predicted_L, name=None):
    with tf.name_scope(name, default_name="routing"):
        raw_weights = tf.zeros([batch_size, caps_Lminus1, caps_L, 1, 1], dtype=np.float32, name="raw_weights")

        for r in range(0, iterations):
            routing_weights = tf.nn.softmax(raw_weights, dim=2, name="routing_weights")
            weighted_predictions = tf.multiply(routing_weights, predicted_L, name="weighted_predictions")
            weighted_sum = tf.reduce_sum(weighted_predictions, axis=(1), keepdims=True, name="weighted_sum")
            output_L = squash(weighted_sum, axis=-2, name="output_L")
            output_tiled_L = tf.tile(output_L, [1, caps_Lminus1, 1, 1, 1], name="output_tiled_L")
            agreement = tf.matmul(predicted_L, output_tiled_L, transpose_a=True, name="agreement")
            raw_weights = tf.add(raw_weights, agreement, name="raw_weights")

        return output_L, routing_weights


def squash(s, axis=-1, epsilon=1e-7, name=None):
    with tf.name_scope(name, default_name="squash"):
        squared_norm = tf.reduce_sum(tf.square(s), axis=axis, keepdims=True)
        safe_norm = tf.sqrt(squared_norm + epsilon)
        squash_factor = squared_norm / (1. + squared_norm)
        unit_vector = s / safe_norm
        return squash_factor * unit_vector


def safe_norm(s, axis=-1, epsilon=1e-7, keep_dims=False, name=None):
    with tf.name_scope(name, default_name="safe_norm"):
        squared_norm = tf.reduce_sum(tf.square(s), axis=axis, keep_dims=keep_dims)
        return tf.sqrt(squared_norm + epsilon)


X = tf.placeholder(shape=[None, input_dimensions[0], input_dimensions[1], input_dimensions[2]], dtype=tf.float32,
                   name="X")
tf.summary.image('X', X)
y = tf.placeholder(shape=[None], dtype=tf.int64, name="y")
# Out:
# WARNING:tensorflow:From C:\Users\Michael\AppData\Local\Temp\ipykernel_7440\1079060265.py:53: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\Michael\AppData\Local\Temp\ipykernel_7440\1079060265.py:55: The name tf.summary.image is deprecated. Please use tf.compat.v1.summary.image instead.

# %% [markdown]
# ## Adjust This Cell As Needed Depending On The Architecture Used

# %%
# Block 1
k = 3
s = 1
x = tf.layers.Conv2D(128, k, s, activation='relu')(X)
x = tf.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)

# Block 2
k = 3
s = 1
x = tf.layers.Conv2D(256, k, s, activation='relu')(x)
x = tf.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(x)

# Block 3
k = 7
s = 1
convcaps_dims = 16
convcaps_caps_types = 32
convcaps = tf.layers.Conv2D(convcaps_dims*convcaps_caps_types, k, s, name="convcaps")(x)
tf.summary.histogram("convcaps", convcaps)

convcaps_grid_length = tf.shape(convcaps)[1]
convcaps_grid_width = tf.shape(convcaps)[2]
convcaps_grid_cells = convcaps_grid_length * convcaps_grid_width
convcaps_caps = convcaps_caps_types * convcaps_grid_cells

convcaps_reshape = tf.reshape(convcaps, [-1, convcaps_caps, convcaps_dims], name="convcaps_reshape")
convcaps_output = squash(convcaps_reshape, name="convcaps_output")

batch_size = tf.shape(X)[0]

# If doing more than 1 capsule layer caps1_caps doesn't need to be the num_classes
caps1_caps = num_classes
caps1_dims = 12

caps1_predictions = predictions(convcaps_caps_types, convcaps_dims, convcaps_output,
                                caps1_caps, caps1_dims, batch_size, True, convcaps_grid_cells, "caps1_predictions")

caps1_output, routing1 = routing(convcaps_caps, caps1_caps,
                                 batch_size, 6, caps1_predictions, "routing1")

# You Can Add More Capsule Layers By Doing:
# Adding a second layer:
# -----------------------
# caps2_caps = 8
# caps2_dims = 16
# 
# caps2_predictions = predictions(caps1_caps, caps1_dims, caps1_output, 
#                                 caps2_caps, caps2_dims, batch_size, False, 1, "caps2_predictions")
#                                                                       ^ remains as False
# caps2_output, routing2 = routing(caps1_caps, caps2_caps, batch_size, 9, caps2_predictions, "routing2")
# 
# Adding a third layer:
# -----------------------
# caps3_caps = num_classes
# caps3_dims = 16
# 
# caps3_predictions = predictions(caps2_caps, caps2_dims, caps2_output, 
#                                 caps3_caps, caps3_dims, batch_size, False, 1, "caps3_predictions")
# 
# 
# caps3_output, routing3 = routing(caps2_caps, caps3_caps, batch_size, 9, caps3_predictions, "routing3")
# 
# Then Modify The Variable Below As Needed

# This Line Is Here To Make Using More Capsules Work Without Modifying Variables Below!
final_capsule_output, final_routing_output = caps1_output, routing1

# If more capsule Layers are introduced, the array below needs to be modified as well!
caps_and_routing = [convcaps_output, routing1, caps1_output]

# If Using More Capsules, The Above List Looks Like This:
# caps_and_routing = [convcaps_output, routing1, caps1_output, routing2, caps2_output, ...]

# Find out how many capsule Layers there are
capsule_layers = (len(caps_and_routing) - 1) / 2
print(f"{capsule_layers} Capsule Layer(s)")

# This can stay the same
caps_and_routing_dims = [convcaps_grid_length, convcaps_grid_width, convcaps_caps_types, num_classes]
# Out:
# WARNING:tensorflow:From C:\Users\Michael\AppData\Local\Temp\ipykernel_7440\1373185723.py:4: The name tf.layers.Conv2D is deprecated. Please use tf.compat.v1.layers.Conv2D instead.
#
# WARNING:tensorflow:From C:\Users\Michael\AppData\Local\Temp\ipykernel_7440\1373185723.py:5: The name tf.layers.MaxPooling2D is deprecated. Please use tf.compat.v1.layers.MaxPooling2D instead.
#
# WARNING:tensorflow:From C:\Users\Michael\AppData\Local\Temp\ipykernel_7440\1373185723.py:19: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# WARNING:tensorflow:From C:\Users\Michael\AppData\Local\Temp\ipykernel_7440\1079060265.py:8: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From C:\Users\Michael\AppData\Local\Temp\ipykernel_7440\1079060265.py:27: calling softmax (from tensorflow.python.ops.nn_ops) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# 1.0 Capsule Layer(s)

# %% [markdown]
# ### Rest of the tempalte code

# %%
with tf.name_scope(name="accuracy_cell"):
    lengths_temp = safe_norm(final_capsule_output, axis=-2, name="lengths_temp")
    lengths = tf.reshape(lengths_temp, shape=(-1, num_classes), name="lengths")
    lengths_argmax = tf.argmax(lengths, axis=1, name="lengths_argmax")
    y_predictions = lengths_argmax
    correct = tf.equal(y, y_predictions, name="correct")
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32), name="accuracy")
    tf.summary.scalar('accuracy', accuracy)

m_plus = 0.9
m_minus = 0.1
lambda_ = 0.5

with tf.name_scope(name="loss_cell"):
    T = tf.one_hot(y, depth=caps1_caps, name="T")
    # Compute norm of each capsule in digitcaps
    caps1_output_norm = safe_norm(final_capsule_output, axis=-2, keep_dims=True, name="caps1_output_norm")

    present_error_raw = tf.square(tf.maximum(0., m_plus - caps1_output_norm), name="present_error_raw")
    present_error = tf.reshape(present_error_raw, shape=(-1, caps1_caps), name="present_error")
    # -1 tells reshape to calculate the size of this dimension.

    absent_error_raw = tf.square(tf.maximum(0., caps1_output_norm - m_minus), name="absent_error_raw")
    absent_error = tf.reshape(absent_error_raw, shape=(-1, caps1_caps), name="absent_error")
    # -1 tells reshape to calculate the size of this dimension.

    # Compute Margin Loss
    L = tf.add(T * present_error, lambda_ * (1.0 - T) * absent_error, name="L")
    loss = tf.reduce_mean(tf.reduce_sum(L, axis=1), name="loss")
    tf.summary.scalar('loss', loss)

# ### Adam Optimizer
# Initialize adam optimizer to minimize $\texttt{loss}$.
with tf.name_scope(name="train"):
    learning_rate = tf.placeholder(tf.float32, shape=[])
    tf.summary.scalar('learning_rate', learning_rate)
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    training_op = optimizer.minimize(loss, name="training_op")

merged_summary = tf.summary.merge_all()
init = tf.global_variables_initializer()
saver = tf.train.Saver()


def visualize_convcaps(caps_and_routing, caps_and_routing_dims, reduce):
    temp_dims = caps_and_routing_dims[0:3] + [1] * (len(caps_and_routing_dims) - 3)
    convcaps_lengths = tf.reshape(safe_norm(caps_and_routing[0], axis=-1), temp_dims)
    temp_dims = [1] * (3) + caps_and_routing_dims[3:len(caps_and_routing_dims)]
    convcaps_lengths_tiled = tf.tile(convcaps_lengths, temp_dims)

    temp_dims = caps_and_routing_dims[0:4] + [1] * (len(caps_and_routing_dims) - 4)
    routing1_reshape = tf.reshape(caps_and_routing[1], temp_dims)
    temp_dims = [1] * (4) + caps_and_routing_dims[4:len(caps_and_routing_dims)]
    routing1_reshape_tiled = tf.tile(routing1_reshape, temp_dims)

    temp_dims = [1, 1, 1, caps_and_routing_dims[3]] + [1] * (len(caps_and_routing_dims) - 4)
    caps1_lengths = tf.reshape(safe_norm(caps_and_routing[2], axis=-2), temp_dims)
    temp_dims = caps_and_routing_dims[0:3] + [1] + caps_and_routing_dims[4:len(caps_and_routing_dims)]
    caps1_lengths_tiled = tf.tile(caps1_lengths, temp_dims)

    temp1 = tf.square(tf.multiply(routing1_reshape_tiled, caps1_lengths_tiled))

    temp_matrices = []
    index = 0
    for i in range(4, len(caps_and_routing_dims)):
        temp_dims = [1] * (i - 1) + caps_and_routing_dims[i - 1:i + 1] + [1] * (len(caps_and_routing_dims) - i - 1)
        routing_reshape = tf.reshape(caps_and_routing[3 + index], temp_dims)
        temp_dims = caps_and_routing_dims[0:i - 1] + [1] * (2) + caps_and_routing_dims[
                                                                 i + 1:len(caps_and_routing_dims)]
        routing_reshape_tiled = tf.tile(routing_reshape, temp_dims)

        temp_dims = [1] * len(caps_and_routing_dims)
        temp_dims[i] = caps_and_routing_dims[i]
        caps_lengths = tf.reshape(safe_norm(caps_and_routing[3 + index + 1], axis=-2), temp_dims)
        temp_dims = caps_and_routing_dims.copy()
        temp_dims[i] = 1
        caps_lengths_tiled = tf.tile(caps_lengths, temp_dims)

        temp = tf.square(tf.multiply(routing_reshape_tiled, caps_lengths_tiled))
        temp_matrices.append(temp)

        index = index + 2

    all_paths = tf.multiply(convcaps_lengths_tiled, temp1)
    for temp_matrice in temp_matrices:
        all_paths = tf.multiply(all_paths, temp_matrice)

    normalizing_factor = np.prod(caps_and_routing_dims[2:len(caps_and_routing_dims)])
    all_paths_average = tf.reduce_sum(all_paths, axis=reduce) / normalizing_factor

    return all_paths_average
# Out:
# WARNING:tensorflow:From C:\Users\Michael\AppData\Local\Temp\ipykernel_7440\1079060265.py:49: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From C:\Users\Michael\AppData\Local\Temp\ipykernel_7440\839322430.py:8: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From C:\Users\Michael\AppData\Local\Temp\ipykernel_7440\839322430.py:37: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From C:\Users\Michael\Desktop\Capsule_Networks_Rpv_Final\.venv\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\Michael\AppData\Local\Temp\ipykernel_7440\839322430.py:40: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From C:\Users\Michael\AppData\Local\Temp\ipykernel_7440\839322430.py:41: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From C:\Users\Michael\AppData\Local\Temp\ipykernel_7440\839322430.py:42: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.

# %% [markdown]
# ## Specify Any Parameters For What Data To Use
# Only need to run the cells below for a new dataset, otherwise simply load the saved npy file below

# %% [markdown]
# ## Load the npy file if it already exists

# %%
loaded_array = np.load('rpv-outputs.npy', allow_pickle=True)

# %% [markdown]
# ## For a new dataset

# %%
# Will Only Use Predictions With A Confidence Above 80%
accuracyThreshold = 0.8

# Will Use Only Correct Examples
onlyCorrect = True

# Starting Index
startIndex = 0

# How Many Images To Sample Given The Requirements
# If This Is None, It will Use All Possible, Otherwise it will take x consecutive images
# amountOfSamples = 5
amountOfSamples = None

# Specify Which Axis To Reduce
# For Simplicity This Views All Capsule Layers But Can Be Modified Like So:
# reduce = [2] <-- only first capsule layer
# reduce = [3] <-- only second capsule layer
# reduce = [2,3] <-- only first and second capsule layer
# reduce = [3,4] <-- only second and third capsule layer
reduce = list(range(2, 2 + int(capsule_layers)))
print(reduce)
# Out:
# [2]

# %% [markdown]
# ## Generate and Save RPV Outputs To View Outputs On Different Runtimes

# %%
# Initialize variables and lists
results = []
correct_samples_collected = 0

with tf.Session() as sess:
    saver.restore(sess, checkpoint_path)

    i = startIndex
    while (amountOfSamples is None or correct_samples_collected < amountOfSamples) and i < len(x_test):
        print(f"{i} / {len(x_test)}")

        # Run the session to get outputs
        out = sess.run([visualize_convcaps(caps_and_routing, caps_and_routing_dims, reduce), y_predictions, lengths],
                       feed_dict={
                           X: x_test[i].reshape([-1, input_dimensions[0], input_dimensions[1], input_dimensions[2]]),
                           y: [y_test[i]]})

        feature_map = out[0]  # Keep the (x, y, num_class) shape
        prediction = out[1][0]  # Predicted value
        ground_truth = y_test[i]  # Actual label
        confidenceScore = out[2].flatten().tolist()  # Confidence scores
        image_index = i  # Index Of Image If It Needs To Be Referenced Elsewhere

        # Check if the prediction meets the criteria
        correct = (prediction == ground_truth)

        # Check the confidence score of the predicted class
        confidence = confidenceScore[prediction]

        if (confidence >= accuracyThreshold) and (not onlyCorrect or correct):
            # Store the feature map, prediction, real value, confidence score and image index as a tuple
            results.append((feature_map, prediction, ground_truth, confidenceScore, image_index))
            correct_samples_collected += 1
            print(f"Saving {i} To Output")

        # Move to the next index
        i += 1

# Optionally, convert the list to a structured array if you want to access by field name
# dtype = [('feature_map', np.float32, (45, 45, 2)), ('prediction', np.float32), ('ground_truth', np.float32),
#          ('confidence_score', np.float32, (2,)), ('image_index', np.int32)]

loaded_array = np.array(results)

# Save the results
# Option To Save Array
np.save('rpv-outputs.npy', loaded_array)
# Out:
# WARNING:tensorflow:From C:\Users\Michael\AppData\Local\Temp\ipykernel_7440\644878828.py:5: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# INFO:tensorflow:Restoring parameters from C:\Users\Michael\Desktop\Model Benchmark\tensorboard\Models\CatOrDogStandard16_lr0.0001/my_capsule_network
# 0 / 2492
# Saving 0 To Output
# 1 / 2492
# 2 / 2492
# Saving 2 To Output
# 3 / 2492
# 4 / 2492
# 5 / 2492
# Saving 5 To Output
# 6 / 2492
# Saving 6 To Output
# 7 / 2492
# 8 / 2492
# Saving 8 To Output
# 9 / 2492
# Saving 9 To Output
# 10 / 2492
# Saving 10 To Output
# 11 / 2492
# Saving 11 To Output
# 12 / 2492
# 13 / 2492
# Saving 13 To Output
# 14 / 2492
# 15 / 2492
# 16 / 2492
# Saving 16 To Output
# 17 / 2492
# Saving 17 To Output
# 18 / 2492
# 19 / 2492
# Saving 19 To Output
# 20 / 2492
# 21 / 2492
# Saving 21 To Output
# 22 / 2492
# 23 / 2492
# 24 / 2492
# 25 / 2492
# 26 / 2492
# 27 / 2492
# 28 / 2492
# 29 / 2492
# Saving 29 To Output
# 30 / 2492
# 31 / 2492
# 32 / 2492
# 33 / 2492
# 34 / 2492
# Saving 34 To Output
# 35 / 2492
# 36 / 2492
# 37 / 2492
# Saving 37 To Output
# 38 / 2492
# Saving 38 To Output
# 39 / 2492
# Saving 39 To Output
# 40 / 2492
# Saving 40 To Output
# 41 / 2492
# 42 / 2492
# Saving 42 To Output
# 43 / 2492
# Saving 43 To Output
# 44 / 2492
# Saving 44 To Output
# 45 / 2492
# 46 / 2492
# Saving 46 To Output
# 47 / 2492
# 48 / 2492
# Saving 48 To Output
# 49 / 2492
# Saving 49 To Output
# 50 / 2492
# Saving 50 To Output
# 51 / 2492
# 52 / 2492
# 53 / 2492
# Saving 53 To Output
# 54 / 2492
# Saving 54 To Output
# 55 / 2492
# Saving 55 To Output
# 56 / 2492
# Saving 56 To Output
# 57 / 2492
# Saving 57 To Output
# 58 / 2492
# 59 / 2492
# Saving 59 To Output
# 60 / 2492
# Saving 60 To Output
# 61 / 2492
# 62 / 2492
# 63 / 2492
# Saving 63 To Output
# 64 / 2492
# Saving 64 To Output
# 65 / 2492
# 66 / 2492
# Saving 66 To Output
# 67 / 2492
# Saving 67 To Output
# 68 / 2492
# Saving 68 To Output
# 69 / 2492
# 70 / 2492
# Saving 70 To Output
# 71 / 2492
# Saving 71 To Output
# 72 / 2492
# Saving 72 To Output
# 73 / 2492
# 74 / 2492
# Saving 74 To Output
# 75 / 2492
# Saving 75 To Output
# 76 / 2492
# Saving 76 To Output
# 77 / 2492
# 78 / 2492
# 79 / 2492
# Saving 79 To Output
# 80 / 2492
# 81 / 2492
# 82 / 2492
# Saving 82 To Output
# 83 / 2492
# Saving 83 To Output
# 84 / 2492
# Saving 84 To Output
# 85 / 2492
# Saving 85 To Output
# 86 / 2492
# Saving 86 To Output
# 87 / 2492
# 88 / 2492
# Saving 88 To Output
# 89 / 2492
# Saving 89 To Output
# 90 / 2492
# 91 / 2492
# 92 / 2492
# Saving 92 To Output
# 93 / 2492
# Saving 93 To Output
# 94 / 2492
# Saving 94 To Output
# 95 / 2492
# Saving 95 To Output
# 96 / 2492
# 97 / 2492
# 98 / 2492
# 99 / 2492
# 100 / 2492
# Saving 100 To Output
# 101 / 2492
# 102 / 2492
# Saving 102 To Output
# 103 / 2492
# Saving 103 To Output
# 104 / 2492
# Saving 104 To Output
# 105 / 2492
# Saving 105 To Output
# 106 / 2492
# Saving 106 To Output
# 107 / 2492
# Saving 107 To Output
# 108 / 2492
# Saving 108 To Output
# 109 / 2492
# 110 / 2492
# Saving 110 To Output
# 111 / 2492
# Saving 111 To Output
# 112 / 2492
# Saving 112 To Output
# 113 / 2492
# 114 / 2492
# 115 / 2492
# 116 / 2492
# Saving 116 To Output
# 117 / 2492
# Saving 117 To Output
# 118 / 2492
# 119 / 2492
# Saving 119 To Output
# 120 / 2492
# Saving 120 To Output
# 121 / 2492
# 122 / 2492
# 123 / 2492
# Saving 123 To Output
# 124 / 2492
# Saving 124 To Output
# 125 / 2492
# 126 / 2492
# 127 / 2492
# 128 / 2492
# Saving 128 To Output
# 129 / 2492
# 130 / 2492
# Saving 130 To Output
# 131 / 2492
# Saving 131 To Output
# 132 / 2492
# Saving 132 To Output
# 133 / 2492
# Saving 133 To Output
# 134 / 2492
# Saving 134 To Output
# 135 / 2492
# 136 / 2492
# Saving 136 To Output
# 137 / 2492
# 138 / 2492
# Saving 138 To Output
# 139 / 2492
# Saving 139 To Output
# 140 / 2492
# Saving 140 To Output
# 141 / 2492
# Saving 141 To Output
# 142 / 2492
# 143 / 2492
# Saving 143 To Output
# 144 / 2492
# Saving 144 To Output
# 145 / 2492
# 146 / 2492
# Saving 146 To Output
# 147 / 2492
# 148 / 2492
# Saving 148 To Output
# 149 / 2492
# 150 / 2492
# 151 / 2492
# Saving 151 To Output
# 152 / 2492
# Saving 152 To Output
# 153 / 2492
# 154 / 2492
# Saving 154 To Output
# 155 / 2492
# 156 / 2492
# 157 / 2492
# 158 / 2492
# Saving 158 To Output
# 159 / 2492
# 160 / 2492
# Saving 160 To Output
# 161 / 2492
# Saving 161 To Output
# 162 / 2492
# Saving 162 To Output
# 163 / 2492
# Saving 163 To Output
# 164 / 2492
# Saving 164 To Output
# 165 / 2492
# Saving 165 To Output
# 166 / 2492
# Saving 166 To Output
# 167 / 2492
# Saving 167 To Output
# 168 / 2492
# 169 / 2492
# 170 / 2492
# Saving 170 To Output
# 171 / 2492
# 172 / 2492
# Saving 172 To Output
# 173 / 2492
# Saving 173 To Output
# 174 / 2492
# Saving 174 To Output
# 175 / 2492
# 176 / 2492
# 177 / 2492
# Saving 177 To Output
# 178 / 2492
# Saving 178 To Output
# 179 / 2492
# Saving 179 To Output
# 180 / 2492
# Saving 180 To Output
# 181 / 2492
# Saving 181 To Output
# 182 / 2492
# Saving 182 To Output
# 183 / 2492
# 184 / 2492
# Saving 184 To Output
# 185 / 2492
# 186 / 2492
# 187 / 2492
# 188 / 2492
# Saving 188 To Output
# 189 / 2492
# 190 / 2492
# 191 / 2492
# Saving 191 To Output
# 192 / 2492
# Saving 192 To Output
# 193 / 2492
# Saving 193 To Output
# 194 / 2492
# Saving 194 To Output
# 195 / 2492
# Saving 195 To Output
# 196 / 2492
# Saving 196 To Output
# 197 / 2492
# 198 / 2492
# Saving 198 To Output
# 199 / 2492
# Saving 199 To Output
# 200 / 2492
# 201 / 2492
# 202 / 2492
# 203 / 2492
# Saving 203 To Output
# 204 / 2492
# Saving 204 To Output
# 205 / 2492
# 206 / 2492
# 207 / 2492
# Saving 207 To Output
# 208 / 2492
# Saving 208 To Output
# 209 / 2492
# 210 / 2492
# 211 / 2492
# Saving 211 To Output
# 212 / 2492
# Saving 212 To Output
# 213 / 2492
# 214 / 2492
# 215 / 2492
# Saving 215 To Output
# 216 / 2492
# 217 / 2492
# Saving 217 To Output
# 218 / 2492
# 219 / 2492
# Saving 219 To Output
# 220 / 2492
# Saving 220 To Output
# 221 / 2492
# Saving 221 To Output
# 222 / 2492
# Saving 222 To Output
# 223 / 2492
# Saving 223 To Output
# 224 / 2492
# 225 / 2492
# 226 / 2492
# Saving 226 To Output
# 227 / 2492
# 228 / 2492
# Saving 228 To Output
# 229 / 2492
# 230 / 2492
# 231 / 2492
# 232 / 2492
# 233 / 2492
# Saving 233 To Output
# 234 / 2492
# 235 / 2492
# 236 / 2492
# 237 / 2492
# 238 / 2492
# Saving 238 To Output
# 239 / 2492
# Saving 239 To Output
# 240 / 2492
# Saving 240 To Output
# 241 / 2492
# Saving 241 To Output
# 242 / 2492
# 243 / 2492
# Saving 243 To Output
# 244 / 2492
# Saving 244 To Output
# 245 / 2492
# 246 / 2492
# Saving 246 To Output
# 247 / 2492
# Saving 247 To Output
# 248 / 2492
# Saving 248 To Output
# 249 / 2492
# 250 / 2492
# Saving 250 To Output
# 251 / 2492
# 252 / 2492
# 253 / 2492
# Saving 253 To Output
# 254 / 2492
# Saving 254 To Output
# 255 / 2492
# Saving 255 To Output
# 256 / 2492
# Saving 256 To Output
# 257 / 2492
# Saving 257 To Output
# 258 / 2492
# 259 / 2492
# 260 / 2492
# Saving 260 To Output
# 261 / 2492
# Saving 261 To Output
# 262 / 2492
# 263 / 2492
# Saving 263 To Output
# 264 / 2492
# Saving 264 To Output
# 265 / 2492
# 266 / 2492
# Saving 266 To Output
# 267 / 2492
# 268 / 2492
# 269 / 2492
# Saving 269 To Output
# 270 / 2492
# Saving 270 To Output
# 271 / 2492
# Saving 271 To Output
# 272 / 2492
# 273 / 2492
# 274 / 2492
# 275 / 2492
# Saving 275 To Output
# 276 / 2492
# Saving 276 To Output
# 277 / 2492
# Saving 277 To Output
# 278 / 2492
# Saving 278 To Output
# 279 / 2492
# 280 / 2492
# Saving 280 To Output
# 281 / 2492
# Saving 281 To Output
# 282 / 2492
# Saving 282 To Output
# 283 / 2492
# Saving 283 To Output
# 284 / 2492
# Saving 284 To Output
# 285 / 2492
# Saving 285 To Output
# 286 / 2492
# Saving 286 To Output
# 287 / 2492
# Saving 287 To Output
# 288 / 2492
# Saving 288 To Output
# 289 / 2492
# Saving 289 To Output
# 290 / 2492
# Saving 290 To Output
# 291 / 2492
# 292 / 2492
# 293 / 2492
# 294 / 2492
# 295 / 2492
# Saving 295 To Output
# 296 / 2492
# 297 / 2492
# 298 / 2492
# 299 / 2492
# 300 / 2492
# 301 / 2492
# Saving 301 To Output
# 302 / 2492
# Saving 302 To Output
# 303 / 2492
# 304 / 2492
# 305 / 2492
# Saving 305 To Output
# 306 / 2492
# 307 / 2492
# Saving 307 To Output
# 308 / 2492
# 309 / 2492
# 310 / 2492
# 311 / 2492
# Saving 311 To Output
# 312 / 2492
# 313 / 2492
# Saving 313 To Output
# 314 / 2492
# 315 / 2492
# Saving 315 To Output
# 316 / 2492
# 317 / 2492
# Saving 317 To Output
# 318 / 2492
# 319 / 2492
# 320 / 2492
# Saving 320 To Output
# 321 / 2492
# 322 / 2492
# 323 / 2492
# Saving 323 To Output
# 324 / 2492
# Saving 324 To Output
# 325 / 2492
# Saving 325 To Output
# 326 / 2492
# 327 / 2492
# 328 / 2492
# Saving 328 To Output
# 329 / 2492
# Saving 329 To Output
# 330 / 2492
# Saving 330 To Output
# 331 / 2492
# Saving 331 To Output
# 332 / 2492
# 333 / 2492
# Saving 333 To Output
# 334 / 2492
# 335 / 2492
# Saving 335 To Output
# 336 / 2492
# 337 / 2492
# Saving 337 To Output
# 338 / 2492
# 339 / 2492
# Saving 339 To Output
# 340 / 2492
# Saving 340 To Output
# 341 / 2492
# 342 / 2492
# Saving 342 To Output
# 343 / 2492
# Saving 343 To Output
# 344 / 2492
# Saving 344 To Output
# 345 / 2492
# 346 / 2492
# Saving 346 To Output
# 347 / 2492
# 348 / 2492
# Saving 348 To Output
# 349 / 2492
# Saving 349 To Output
# 350 / 2492
# Saving 350 To Output
# 351 / 2492
# Saving 351 To Output
# 352 / 2492
# Saving 352 To Output
# 353 / 2492
# Saving 353 To Output
# 354 / 2492
# 355 / 2492
# Saving 355 To Output
# 356 / 2492
# Saving 356 To Output
# 357 / 2492
# Saving 357 To Output
# 358 / 2492
# 359 / 2492
# Saving 359 To Output
# 360 / 2492
# Saving 360 To Output
# 361 / 2492
# Saving 361 To Output
# 362 / 2492
# Saving 362 To Output
# 363 / 2492
# 364 / 2492
# 365 / 2492
# 366 / 2492
# 367 / 2492
# 368 / 2492
# 369 / 2492
# 370 / 2492
# Saving 370 To Output
# 371 / 2492
# Saving 371 To Output
# 372 / 2492
# Saving 372 To Output
# 373 / 2492
# 374 / 2492
# Saving 374 To Output
# 375 / 2492
# 376 / 2492
# Saving 376 To Output
# 377 / 2492
# 378 / 2492
# Saving 378 To Output
# 379 / 2492
# 380 / 2492
# Saving 380 To Output
# 381 / 2492
# Saving 381 To Output
# 382 / 2492
# 383 / 2492
# Saving 383 To Output
# 384 / 2492
# Saving 384 To Output
# 385 / 2492
# 386 / 2492
# 387 / 2492
# Saving 387 To Output
# 388 / 2492
# 389 / 2492
# Saving 389 To Output
# 390 / 2492
# Saving 390 To Output
# 391 / 2492
# 392 / 2492
# Saving 392 To Output
# 393 / 2492
# Saving 393 To Output
# 394 / 2492
# Saving 394 To Output
# 395 / 2492
# Saving 395 To Output
# 396 / 2492
# Saving 396 To Output
# 397 / 2492
# Saving 397 To Output
# 398 / 2492
# 399 / 2492
# Saving 399 To Output
# 400 / 2492
# Saving 400 To Output
# 401 / 2492
# Saving 401 To Output
# 402 / 2492
# Saving 402 To Output
# 403 / 2492
# 404 / 2492
# 405 / 2492
# 406 / 2492
# Saving 406 To Output
# 407 / 2492
# 408 / 2492
# Saving 408 To Output
# 409 / 2492
# 410 / 2492
# Saving 410 To Output
# 411 / 2492
# 412 / 2492
# Saving 412 To Output
# 413 / 2492
# Saving 413 To Output
# 414 / 2492
# 415 / 2492
# Saving 415 To Output
# 416 / 2492
# 417 / 2492
# 418 / 2492
# Saving 418 To Output
# 419 / 2492
# Saving 419 To Output
# 420 / 2492
# 421 / 2492
# Saving 421 To Output
# 422 / 2492
# Saving 422 To Output
# 423 / 2492
# 424 / 2492
# 425 / 2492
# 426 / 2492
# Saving 426 To Output
# 427 / 2492
# Saving 427 To Output
# 428 / 2492
# Saving 428 To Output
# 429 / 2492
# Saving 429 To Output
# 430 / 2492
# 431 / 2492
# Saving 431 To Output
# 432 / 2492
# Saving 432 To Output
# 433 / 2492
# 434 / 2492
# Saving 434 To Output
# 435 / 2492
# 436 / 2492
# 437 / 2492
# Saving 437 To Output
# 438 / 2492
# 439 / 2492
# Saving 439 To Output
# 440 / 2492
# 441 / 2492
# Saving 441 To Output
# 442 / 2492
# Saving 442 To Output
# 443 / 2492
# Saving 443 To Output
# 444 / 2492
# 445 / 2492
# 446 / 2492
# Saving 446 To Output
# 447 / 2492
# Saving 447 To Output
# 448 / 2492
# Saving 448 To Output
# 449 / 2492
# Saving 449 To Output
# 450 / 2492
# Saving 450 To Output
# 451 / 2492
# 452 / 2492
# Saving 452 To Output
# 453 / 2492
# 454 / 2492
# 455 / 2492
# Saving 455 To Output
# 456 / 2492
# Saving 456 To Output
# 457 / 2492
# 458 / 2492
# Saving 458 To Output
# 459 / 2492
# Saving 459 To Output
# 460 / 2492
# 461 / 2492
# Saving 461 To Output
# 462 / 2492
# 463 / 2492
# Saving 463 To Output
# 464 / 2492
# 465 / 2492
# Saving 465 To Output
# 466 / 2492
# 467 / 2492
# Saving 467 To Output
# 468 / 2492
# 469 / 2492
# Saving 469 To Output
# 470 / 2492
# Saving 470 To Output
# 471 / 2492
# Saving 471 To Output
# 472 / 2492
# 473 / 2492
# Saving 473 To Output
# 474 / 2492
# Saving 474 To Output
# 475 / 2492
# 476 / 2492
# 477 / 2492
# Saving 477 To Output
# 478 / 2492
# 479 / 2492
# 480 / 2492
# 481 / 2492
# Saving 481 To Output
# 482 / 2492
# Saving 482 To Output
# 483 / 2492
# Saving 483 To Output
# 484 / 2492
# 485 / 2492
# 486 / 2492
# Saving 486 To Output
# 487 / 2492
# Saving 487 To Output
# 488 / 2492
# Saving 488 To Output
# 489 / 2492
# 490 / 2492
# Saving 490 To Output
# 491 / 2492
# 492 / 2492
# Saving 492 To Output
# 493 / 2492
# 494 / 2492
# 495 / 2492
# Saving 495 To Output
# 496 / 2492
# Saving 496 To Output
# 497 / 2492
# 498 / 2492
# Saving 498 To Output
# 499 / 2492
# 500 / 2492
# Saving 500 To Output
# 501 / 2492
# Saving 501 To Output
# 502 / 2492
# Saving 502 To Output
# 503 / 2492
# Saving 503 To Output
# 504 / 2492
# Saving 504 To Output
# 505 / 2492
# 506 / 2492
# Saving 506 To Output
# 507 / 2492
# 508 / 2492
# 509 / 2492
# Saving 509 To Output
# 510 / 2492
# Saving 510 To Output
# 511 / 2492
# 512 / 2492
# Saving 512 To Output
# 513 / 2492
# Saving 513 To Output
# 514 / 2492
# 515 / 2492
# 516 / 2492
# Saving 516 To Output
# 517 / 2492
# Saving 517 To Output
# 518 / 2492
# Saving 518 To Output
# 519 / 2492
# Saving 519 To Output
# 520 / 2492
# 521 / 2492
# Saving 521 To Output
# 522 / 2492
# 523 / 2492
# Saving 523 To Output
# 524 / 2492
# Saving 524 To Output
# 525 / 2492
# Saving 525 To Output
# 526 / 2492
# Saving 526 To Output
# 527 / 2492
# 528 / 2492
# Saving 528 To Output
# 529 / 2492
# Saving 529 To Output
# 530 / 2492
# Saving 530 To Output
# 531 / 2492
# Saving 531 To Output
# 532 / 2492
# Saving 532 To Output
# 533 / 2492
# Saving 533 To Output
# 534 / 2492
# 535 / 2492
# Saving 535 To Output
# 536 / 2492
# Saving 536 To Output
# 537 / 2492
# 538 / 2492
# Saving 538 To Output
# 539 / 2492
# 540 / 2492
# Saving 540 To Output
# 541 / 2492
# Saving 541 To Output
# 542 / 2492
# 543 / 2492
# Saving 543 To Output
# 544 / 2492
# Saving 544 To Output
# 545 / 2492
# 546 / 2492
# Saving 546 To Output
# 547 / 2492
# 548 / 2492
# 549 / 2492
# 550 / 2492
# 551 / 2492
# 552 / 2492
# 553 / 2492
# 554 / 2492
# Saving 554 To Output
# 555 / 2492
# 556 / 2492
# Saving 556 To Output
# 557 / 2492
# Saving 557 To Output
# 558 / 2492
# Saving 558 To Output
# 559 / 2492
# Saving 559 To Output
# 560 / 2492
# Saving 560 To Output
# 561 / 2492
# Saving 561 To Output
# 562 / 2492
# Saving 562 To Output
# 563 / 2492
# Saving 563 To Output
# 564 / 2492
# Saving 564 To Output
# 565 / 2492
# Saving 565 To Output
# 566 / 2492
# 567 / 2492
# Saving 567 To Output
# 568 / 2492
# Saving 568 To Output
# 569 / 2492
# 570 / 2492
# 571 / 2492
# 572 / 2492
# 573 / 2492
# Saving 573 To Output
# 574 / 2492
# 575 / 2492
# 576 / 2492
# Saving 576 To Output
# 577 / 2492
# 578 / 2492
# Saving 578 To Output
# 579 / 2492
# Saving 579 To Output
# 580 / 2492
# Saving 580 To Output
# 581 / 2492
# 582 / 2492
# Saving 582 To Output
# 583 / 2492
# 584 / 2492
# Saving 584 To Output
# 585 / 2492
# Saving 585 To Output
# 586 / 2492
# Saving 586 To Output
# 587 / 2492
# 588 / 2492
# Saving 588 To Output
# 589 / 2492
# Saving 589 To Output
# 590 / 2492
# Saving 590 To Output
# 591 / 2492
# Saving 591 To Output
# 592 / 2492
# 593 / 2492
# 594 / 2492
# 595 / 2492
# Saving 595 To Output
# 596 / 2492
# Saving 596 To Output
# 597 / 2492
# Saving 597 To Output
# 598 / 2492
# Saving 598 To Output
# 599 / 2492
# Saving 599 To Output
# 600 / 2492
# 601 / 2492
# 602 / 2492
# Saving 602 To Output
# 603 / 2492
# Saving 603 To Output
# 604 / 2492
# Saving 604 To Output
# 605 / 2492
# Saving 605 To Output
# 606 / 2492
# Saving 606 To Output
# 607 / 2492
# Saving 607 To Output
# 608 / 2492
# Saving 608 To Output
# 609 / 2492
# Saving 609 To Output
# 610 / 2492
# Saving 610 To Output
# 611 / 2492
# 612 / 2492
# Saving 612 To Output
# 613 / 2492
# 614 / 2492
# 615 / 2492
# 616 / 2492
# Saving 616 To Output
# 617 / 2492
# Saving 617 To Output
# 618 / 2492
# 619 / 2492
# 620 / 2492
# Saving 620 To Output
# 621 / 2492
# Saving 621 To Output
# 622 / 2492
# Saving 622 To Output
# 623 / 2492
# Saving 623 To Output
# 624 / 2492
# Saving 624 To Output
# 625 / 2492
# 626 / 2492
# 627 / 2492
# 628 / 2492
# 629 / 2492
# Saving 629 To Output
# 630 / 2492
# 631 / 2492
# Saving 631 To Output
# 632 / 2492
# 633 / 2492
# Saving 633 To Output
# 634 / 2492
# Saving 634 To Output
# 635 / 2492
# Saving 635 To Output
# 636 / 2492
# Saving 636 To Output
# 637 / 2492
# 638 / 2492
# 639 / 2492
# Saving 639 To Output
# 640 / 2492
# 641 / 2492
# Saving 641 To Output
# 642 / 2492
# Saving 642 To Output
# 643 / 2492
# Saving 643 To Output
# 644 / 2492
# Saving 644 To Output
# 645 / 2492
# 646 / 2492
# Saving 646 To Output
# 647 / 2492
# Saving 647 To Output
# 648 / 2492
# 649 / 2492
# Saving 649 To Output
# 650 / 2492
# Saving 650 To Output
# 651 / 2492
# Saving 651 To Output
# 652 / 2492
# Saving 652 To Output
# 653 / 2492
# 654 / 2492
# Saving 654 To Output
# 655 / 2492
# 656 / 2492
# Saving 656 To Output
# 657 / 2492
# Saving 657 To Output
# 658 / 2492
# 659 / 2492
# 660 / 2492
# Saving 660 To Output
# 661 / 2492
# Saving 661 To Output
# 662 / 2492
# 663 / 2492
# 664 / 2492
# Saving 664 To Output
# 665 / 2492
# Saving 665 To Output
# 666 / 2492
# 667 / 2492
# Saving 667 To Output
# 668 / 2492
# Saving 668 To Output
# 669 / 2492
# 670 / 2492
# 671 / 2492
# 672 / 2492
# Saving 672 To Output
# 673 / 2492
# Saving 673 To Output
# 674 / 2492
# 675 / 2492
# Saving 675 To Output
# 676 / 2492
# Saving 676 To Output
# 677 / 2492
# Saving 677 To Output
# 678 / 2492
# Saving 678 To Output
# 679 / 2492
# Saving 679 To Output
# 680 / 2492
# 681 / 2492
# Saving 681 To Output
# 682 / 2492
# Saving 682 To Output
# 683 / 2492
# 684 / 2492
# 685 / 2492
# 686 / 2492
# 687 / 2492
# Saving 687 To Output
# 688 / 2492
# 689 / 2492
# Saving 689 To Output
# 690 / 2492
# Saving 690 To Output
# 691 / 2492
# Saving 691 To Output
# 692 / 2492
# 693 / 2492
# Saving 693 To Output
# 694 / 2492
# Saving 694 To Output
# 695 / 2492
# 696 / 2492
# 697 / 2492
# Saving 697 To Output
# 698 / 2492
# 699 / 2492
# Saving 699 To Output
# 700 / 2492
# Saving 700 To Output
# 701 / 2492
# 702 / 2492
# 703 / 2492
# Saving 703 To Output
# 704 / 2492
# Saving 704 To Output
# 705 / 2492
# Saving 705 To Output
# 706 / 2492
# Saving 706 To Output
# 707 / 2492
# Saving 707 To Output
# 708 / 2492
# 709 / 2492
# 710 / 2492
# 711 / 2492
# 712 / 2492
# Saving 712 To Output
# 713 / 2492
# 714 / 2492
# 715 / 2492
# Saving 715 To Output
# 716 / 2492
# Saving 716 To Output
# 717 / 2492
# Saving 717 To Output
# 718 / 2492
# 719 / 2492
# 720 / 2492
# Saving 720 To Output
# 721 / 2492
# Saving 721 To Output
# 722 / 2492
# Saving 722 To Output
# 723 / 2492
# Saving 723 To Output
# 724 / 2492
# 725 / 2492
# Saving 725 To Output
# 726 / 2492
# Saving 726 To Output
# 727 / 2492
# Saving 727 To Output
# 728 / 2492
# Saving 728 To Output
# 729 / 2492
# 730 / 2492
# Saving 730 To Output
# 731 / 2492
# Saving 731 To Output
# 732 / 2492
# Saving 732 To Output
# 733 / 2492
# Saving 733 To Output
# 734 / 2492
# Saving 734 To Output
# 735 / 2492
# 736 / 2492
# 737 / 2492
# 738 / 2492
# Saving 738 To Output
# 739 / 2492
# Saving 739 To Output
# 740 / 2492
# Saving 740 To Output
# 741 / 2492
# Saving 741 To Output
# 742 / 2492
# Saving 742 To Output
# 743 / 2492
# 744 / 2492
# 745 / 2492
# 746 / 2492
# Saving 746 To Output
# 747 / 2492
# Saving 747 To Output
# 748 / 2492
# Saving 748 To Output
# 749 / 2492
# 750 / 2492
# Saving 750 To Output
# 751 / 2492
# Saving 751 To Output
# 752 / 2492
# 753 / 2492
# Saving 753 To Output
# 754 / 2492
# 755 / 2492
# Saving 755 To Output
# 756 / 2492
# 757 / 2492
# Saving 757 To Output
# 758 / 2492
# 759 / 2492
# Saving 759 To Output
# 760 / 2492
# Saving 760 To Output
# 761 / 2492
# Saving 761 To Output
# 762 / 2492
# Saving 762 To Output
# 763 / 2492
# Saving 763 To Output
# 764 / 2492
# 765 / 2492
# 766 / 2492
# 767 / 2492
# Saving 767 To Output
# 768 / 2492
# Saving 768 To Output
# 769 / 2492
# 770 / 2492
# 771 / 2492
# Saving 771 To Output
# 772 / 2492
# Saving 772 To Output
# 773 / 2492
# 774 / 2492
# 775 / 2492
# Saving 775 To Output
# 776 / 2492
# Saving 776 To Output
# 777 / 2492
# Saving 777 To Output
# 778 / 2492
# 779 / 2492
# Saving 779 To Output
# 780 / 2492
# Saving 780 To Output
# 781 / 2492
# Saving 781 To Output
# 782 / 2492
# Saving 782 To Output
# 783 / 2492
# 784 / 2492
# Saving 784 To Output
# 785 / 2492
# 786 / 2492
# 787 / 2492
# Saving 787 To Output
# 788 / 2492
# Saving 788 To Output
# 789 / 2492
# 790 / 2492
# Saving 790 To Output
# 791 / 2492
# Saving 791 To Output
# 792 / 2492
# Saving 792 To Output
# 793 / 2492
# Saving 793 To Output
# 794 / 2492
# Saving 794 To Output
# 795 / 2492
# Saving 795 To Output
# 796 / 2492
# Saving 796 To Output
# 797 / 2492
# Saving 797 To Output
# 798 / 2492
# 799 / 2492
# 800 / 2492
# Saving 800 To Output
# 801 / 2492
# 802 / 2492
# Saving 802 To Output
# 803 / 2492
# Saving 803 To Output
# 804 / 2492
# 805 / 2492
# Saving 805 To Output
# 806 / 2492
# Saving 806 To Output
# 807 / 2492
# Saving 807 To Output
# 808 / 2492
# Saving 808 To Output
# 809 / 2492
# Saving 809 To Output
# 810 / 2492
# Saving 810 To Output
# 811 / 2492
# Saving 811 To Output
# 812 / 2492
# Saving 812 To Output
# 813 / 2492
# Saving 813 To Output
# 814 / 2492
# Saving 814 To Output
# 815 / 2492
# 816 / 2492
# Saving 816 To Output
# 817 / 2492
# 818 / 2492
# 819 / 2492
# Saving 819 To Output
# 820 / 2492
# Saving 820 To Output
# 821 / 2492
# 822 / 2492
# 823 / 2492
# 824 / 2492
# 825 / 2492
# Saving 825 To Output
# 826 / 2492
# 827 / 2492
# Saving 827 To Output
# 828 / 2492
# Saving 828 To Output
# 829 / 2492
# Saving 829 To Output
# 830 / 2492
# 831 / 2492
# 832 / 2492
# Saving 832 To Output
# 833 / 2492
# Saving 833 To Output
# 834 / 2492
# 835 / 2492
# Saving 835 To Output
# 836 / 2492
# 837 / 2492
# 838 / 2492
# 839 / 2492
# Saving 839 To Output
# 840 / 2492
# 841 / 2492
# Saving 841 To Output
# 842 / 2492
# 843 / 2492
# Saving 843 To Output
# 844 / 2492
# Saving 844 To Output
# 845 / 2492
# Saving 845 To Output
# 846 / 2492
# 847 / 2492
# 848 / 2492
# 849 / 2492
# Saving 849 To Output
# 850 / 2492
# Saving 850 To Output
# 851 / 2492
# Saving 851 To Output
# 852 / 2492
# Saving 852 To Output
# 853 / 2492
# Saving 853 To Output
# 854 / 2492
# 855 / 2492
# Saving 855 To Output
# 856 / 2492
# 857 / 2492
# 858 / 2492
# Saving 858 To Output
# 859 / 2492
# 860 / 2492
# Saving 860 To Output
# 861 / 2492
# 862 / 2492
# 863 / 2492
# Saving 863 To Output
# 864 / 2492
# Saving 864 To Output
# 865 / 2492
# 866 / 2492
# 867 / 2492
# Saving 867 To Output
# 868 / 2492
# Saving 868 To Output
# 869 / 2492
# Saving 869 To Output
# 870 / 2492
# Saving 870 To Output
# 871 / 2492
# Saving 871 To Output
# 872 / 2492
# 873 / 2492
# Saving 873 To Output
# 874 / 2492
# Saving 874 To Output
# 875 / 2492
# 876 / 2492
# Saving 876 To Output
# 877 / 2492
# 878 / 2492
# 879 / 2492
# 880 / 2492
# 881 / 2492
# Saving 881 To Output
# 882 / 2492
# Saving 882 To Output
# 883 / 2492
# Saving 883 To Output
# 884 / 2492
# Saving 884 To Output
# 885 / 2492
# 886 / 2492
# Saving 886 To Output
# 887 / 2492
# Saving 887 To Output
# 888 / 2492
# Saving 888 To Output
# 889 / 2492
# Saving 889 To Output
# 890 / 2492
# Saving 890 To Output
# 891 / 2492
# 892 / 2492
# 893 / 2492
# Saving 893 To Output
# 894 / 2492
# 895 / 2492
# Saving 895 To Output
# 896 / 2492
# Saving 896 To Output
# 897 / 2492
# Saving 897 To Output
# 898 / 2492
# Saving 898 To Output
# 899 / 2492
# Saving 899 To Output
# 900 / 2492
# 901 / 2492
# Saving 901 To Output
# 902 / 2492
# Saving 902 To Output
# 903 / 2492
# 904 / 2492
# Saving 904 To Output
# 905 / 2492
# 906 / 2492
# 907 / 2492
# Saving 907 To Output
# 908 / 2492
# Saving 908 To Output
# 909 / 2492
# Saving 909 To Output
# 910 / 2492
# 911 / 2492
# Saving 911 To Output
# 912 / 2492
# Saving 912 To Output
# 913 / 2492
# Saving 913 To Output
# 914 / 2492
# Saving 914 To Output
# 915 / 2492
# Saving 915 To Output
# 916 / 2492
# 917 / 2492
# Saving 917 To Output
# 918 / 2492
# Saving 918 To Output
# 919 / 2492
# 920 / 2492
# Saving 920 To Output
# 921 / 2492
# 922 / 2492
# 923 / 2492
# 924 / 2492
# Saving 924 To Output
# 925 / 2492
# 926 / 2492
# 927 / 2492
# 928 / 2492
# Saving 928 To Output
# 929 / 2492
# 930 / 2492
# Saving 930 To Output
# 931 / 2492
# Saving 931 To Output
# 932 / 2492
# Saving 932 To Output
# 933 / 2492
# 934 / 2492
# Saving 934 To Output
# 935 / 2492
# Saving 935 To Output
# 936 / 2492
# 937 / 2492
# Saving 937 To Output
# 938 / 2492
# Saving 938 To Output
# 939 / 2492
# 940 / 2492
# Saving 940 To Output
# 941 / 2492
# Saving 941 To Output
# 942 / 2492
# 943 / 2492
# 944 / 2492
# Saving 944 To Output
# 945 / 2492
# Saving 945 To Output
# 946 / 2492
# Saving 946 To Output
# 947 / 2492
# 948 / 2492
# Saving 948 To Output
# 949 / 2492
# 950 / 2492
# Saving 950 To Output
# 951 / 2492
# Saving 951 To Output
# 952 / 2492
# Saving 952 To Output
# 953 / 2492
# 954 / 2492
# 955 / 2492
# Saving 955 To Output
# 956 / 2492
# Saving 956 To Output
# 957 / 2492
# Saving 957 To Output
# 958 / 2492
# 959 / 2492
# Saving 959 To Output
# 960 / 2492
# 961 / 2492
# Saving 961 To Output
# 962 / 2492
# 963 / 2492
# Saving 963 To Output
# 964 / 2492
# Saving 964 To Output
# 965 / 2492
# Saving 965 To Output
# 966 / 2492
# Saving 966 To Output
# 967 / 2492
# Saving 967 To Output
# 968 / 2492
# 969 / 2492
# 970 / 2492
# 971 / 2492
# 972 / 2492
# Saving 972 To Output
# 973 / 2492
# Saving 973 To Output
# 974 / 2492
# Saving 974 To Output
# 975 / 2492
# Saving 975 To Output
# 976 / 2492
# Saving 976 To Output
# 977 / 2492
# 978 / 2492
# 979 / 2492
# 980 / 2492
# Saving 980 To Output
# 981 / 2492
# 982 / 2492
# Saving 982 To Output
# 983 / 2492
# 984 / 2492
# 985 / 2492
# Saving 985 To Output
# 986 / 2492
# Saving 986 To Output
# 987 / 2492
# Saving 987 To Output
# 988 / 2492
# 989 / 2492
# Saving 989 To Output
# 990 / 2492
# 991 / 2492
# 992 / 2492
# Saving 992 To Output
# 993 / 2492
# 994 / 2492
# Saving 994 To Output
# 995 / 2492
# 996 / 2492
# Saving 996 To Output
# 997 / 2492
# 998 / 2492
# 999 / 2492
# Saving 999 To Output
# 1000 / 2492
# Saving 1000 To Output
# 1001 / 2492
# Saving 1001 To Output
# 1002 / 2492
# 1003 / 2492
# Saving 1003 To Output
# 1004 / 2492
# 1005 / 2492
# Saving 1005 To Output
# 1006 / 2492
# Saving 1006 To Output
# 1007 / 2492
# 1008 / 2492
# 1009 / 2492
# Saving 1009 To Output
# 1010 / 2492
# Saving 1010 To Output
# 1011 / 2492
# Saving 1011 To Output
# 1012 / 2492
# Saving 1012 To Output
# 1013 / 2492
# Saving 1013 To Output
# 1014 / 2492
# 1015 / 2492
# Saving 1015 To Output
# 1016 / 2492
# Saving 1016 To Output
# 1017 / 2492
# Saving 1017 To Output
# 1018 / 2492
# 1019 / 2492
# Saving 1019 To Output
# 1020 / 2492
# Saving 1020 To Output
# 1021 / 2492
# Saving 1021 To Output
# 1022 / 2492
# Saving 1022 To Output
# 1023 / 2492
# 1024 / 2492
# 1025 / 2492
# 1026 / 2492
# Saving 1026 To Output
# 1027 / 2492
# Saving 1027 To Output
# 1028 / 2492
# Saving 1028 To Output
# 1029 / 2492
# Saving 1029 To Output
# 1030 / 2492
# 1031 / 2492
# Saving 1031 To Output
# 1032 / 2492
# Saving 1032 To Output
# 1033 / 2492
# Saving 1033 To Output
# 1034 / 2492
# 1035 / 2492
# 1036 / 2492
# Saving 1036 To Output
# 1037 / 2492
# 1038 / 2492
# Saving 1038 To Output
# 1039 / 2492
# 1040 / 2492
# 1041 / 2492
# 1042 / 2492
# Saving 1042 To Output
# 1043 / 2492
# 1044 / 2492
# Saving 1044 To Output
# 1045 / 2492
# Saving 1045 To Output
# 1046 / 2492
# Saving 1046 To Output
# 1047 / 2492
# 1048 / 2492
# Saving 1048 To Output
# 1049 / 2492
# Saving 1049 To Output
# 1050 / 2492
# 1051 / 2492
# 1052 / 2492
# 1053 / 2492
# 1054 / 2492
# 1055 / 2492
# 1056 / 2492
# 1057 / 2492
# Saving 1057 To Output
# 1058 / 2492
# 1059 / 2492
# Saving 1059 To Output
# 1060 / 2492
# 1061 / 2492
# Saving 1061 To Output
# 1062 / 2492
# 1063 / 2492
# Saving 1063 To Output
# 1064 / 2492
# Saving 1064 To Output
# 1065 / 2492
# 1066 / 2492
# 1067 / 2492
# 1068 / 2492
# Saving 1068 To Output
# 1069 / 2492
# 1070 / 2492
# 1071 / 2492
# Saving 1071 To Output
# 1072 / 2492
# Saving 1072 To Output
# 1073 / 2492
# Saving 1073 To Output
# 1074 / 2492
# 1075 / 2492
# 1076 / 2492
# 1077 / 2492
# 1078 / 2492
# Saving 1078 To Output
# 1079 / 2492
# Saving 1079 To Output
# 1080 / 2492
# 1081 / 2492
# 1082 / 2492
# Saving 1082 To Output
# 1083 / 2492
# 1084 / 2492
# Saving 1084 To Output
# 1085 / 2492
# 1086 / 2492
# 1087 / 2492
# Saving 1087 To Output
# 1088 / 2492
# Saving 1088 To Output
# 1089 / 2492
# Saving 1089 To Output
# 1090 / 2492
# Saving 1090 To Output
# 1091 / 2492
# Saving 1091 To Output
# 1092 / 2492
# Saving 1092 To Output
# 1093 / 2492
# Saving 1093 To Output
# 1094 / 2492
# Saving 1094 To Output
# 1095 / 2492
# 1096 / 2492
# 1097 / 2492
# Saving 1097 To Output
# 1098 / 2492
# 1099 / 2492
# 1100 / 2492
# Saving 1100 To Output
# 1101 / 2492
# Saving 1101 To Output
# 1102 / 2492
# 1103 / 2492
# 1104 / 2492
# 1105 / 2492
# 1106 / 2492
# 1107 / 2492
# Saving 1107 To Output
# 1108 / 2492
# Saving 1108 To Output
# 1109 / 2492
# 1110 / 2492
# 1111 / 2492
# Saving 1111 To Output
# 1112 / 2492
# Saving 1112 To Output
# 1113 / 2492
# Saving 1113 To Output
# 1114 / 2492
# Saving 1114 To Output
# 1115 / 2492
# Saving 1115 To Output
# 1116 / 2492
# Saving 1116 To Output
# 1117 / 2492
# 1118 / 2492
# 1119 / 2492
# 1120 / 2492
# 1121 / 2492
# Saving 1121 To Output
# 1122 / 2492
# 1123 / 2492
# 1124 / 2492
# 1125 / 2492
# Saving 1125 To Output
# 1126 / 2492
# 1127 / 2492
# Saving 1127 To Output
# 1128 / 2492
# 1129 / 2492
# Saving 1129 To Output
# 1130 / 2492
# 1131 / 2492
# Saving 1131 To Output
# 1132 / 2492
# Saving 1132 To Output
# 1133 / 2492
# 1134 / 2492
# Saving 1134 To Output
# 1135 / 2492
# Saving 1135 To Output
# 1136 / 2492
# 1137 / 2492
# Saving 1137 To Output
# 1138 / 2492
# Saving 1138 To Output
# 1139 / 2492
# 1140 / 2492
# Saving 1140 To Output
# 1141 / 2492
# Saving 1141 To Output
# 1142 / 2492
# Saving 1142 To Output
# 1143 / 2492
# 1144 / 2492
# Saving 1144 To Output
# 1145 / 2492
# 1146 / 2492
# 1147 / 2492
# 1148 / 2492
# Saving 1148 To Output
# 1149 / 2492
# Saving 1149 To Output
# 1150 / 2492
# Saving 1150 To Output
# 1151 / 2492
# Saving 1151 To Output
# 1152 / 2492
# 1153 / 2492
# 1154 / 2492
# Saving 1154 To Output
# 1155 / 2492
# 1156 / 2492
# 1157 / 2492
# 1158 / 2492
# Saving 1158 To Output
# 1159 / 2492
# 1160 / 2492
# Saving 1160 To Output
# 1161 / 2492
# Saving 1161 To Output
# 1162 / 2492
# 1163 / 2492
# 1164 / 2492
# 1165 / 2492
# Saving 1165 To Output
# 1166 / 2492
# 1167 / 2492
# Saving 1167 To Output
# 1168 / 2492
# 1169 / 2492
# Saving 1169 To Output
# 1170 / 2492
# Saving 1170 To Output
# 1171 / 2492
# Saving 1171 To Output
# 1172 / 2492
# Saving 1172 To Output
# 1173 / 2492
# 1174 / 2492
# 1175 / 2492
# Saving 1175 To Output
# 1176 / 2492
# 1177 / 2492
# Saving 1177 To Output
# 1178 / 2492
# Saving 1178 To Output
# 1179 / 2492
# 1180 / 2492
# Saving 1180 To Output
# 1181 / 2492
# Saving 1181 To Output
# 1182 / 2492
# Saving 1182 To Output
# 1183 / 2492
# 1184 / 2492
# Saving 1184 To Output
# 1185 / 2492
# 1186 / 2492
# Saving 1186 To Output
# 1187 / 2492
# 1188 / 2492
# Saving 1188 To Output
# 1189 / 2492
# Saving 1189 To Output
# 1190 / 2492
# 1191 / 2492
# 1192 / 2492
# Saving 1192 To Output
# 1193 / 2492
# Saving 1193 To Output
# 1194 / 2492
# Saving 1194 To Output
# 1195 / 2492
# Saving 1195 To Output
# 1196 / 2492
# 1197 / 2492
# Saving 1197 To Output
# 1198 / 2492
# Saving 1198 To Output
# 1199 / 2492
# 1200 / 2492
# 1201 / 2492
# 1202 / 2492
# Saving 1202 To Output
# 1203 / 2492
# Saving 1203 To Output
# 1204 / 2492
# 1205 / 2492
# Saving 1205 To Output
# 1206 / 2492
# 1207 / 2492
# Saving 1207 To Output
# 1208 / 2492
# Saving 1208 To Output
# 1209 / 2492
# Saving 1209 To Output
# 1210 / 2492
# Saving 1210 To Output
# 1211 / 2492
# 1212 / 2492
# 1213 / 2492
# Saving 1213 To Output
# 1214 / 2492
# Saving 1214 To Output
# 1215 / 2492
# 1216 / 2492
# Saving 1216 To Output
# 1217 / 2492
# Saving 1217 To Output
# 1218 / 2492
# Saving 1218 To Output
# 1219 / 2492
# 1220 / 2492
# Saving 1220 To Output
# 1221 / 2492
# 1222 / 2492
# Saving 1222 To Output
# 1223 / 2492
# 1224 / 2492
# Saving 1224 To Output
# 1225 / 2492
# 1226 / 2492
# 1227 / 2492
# 1228 / 2492
# 1229 / 2492
# 1230 / 2492
# 1231 / 2492
# 1232 / 2492
# Saving 1232 To Output
# 1233 / 2492
# Saving 1233 To Output
# 1234 / 2492
# Saving 1234 To Output
# 1235 / 2492
# Saving 1235 To Output
# 1236 / 2492
# Saving 1236 To Output
# 1237 / 2492
# Saving 1237 To Output
# 1238 / 2492
# Saving 1238 To Output
# 1239 / 2492
# Saving 1239 To Output
# 1240 / 2492
# Saving 1240 To Output
# 1241 / 2492
# 1242 / 2492
# 1243 / 2492
# Saving 1243 To Output
# 1244 / 2492
# Saving 1244 To Output
# 1245 / 2492
# Saving 1245 To Output
# 1246 / 2492
# Saving 1246 To Output
# 1247 / 2492
# Saving 1247 To Output
# 1248 / 2492
# 1249 / 2492
# 1250 / 2492
# Saving 1250 To Output
# 1251 / 2492
# Saving 1251 To Output
# 1252 / 2492
# Saving 1252 To Output
# 1253 / 2492
# 1254 / 2492
# 1255 / 2492
# Saving 1255 To Output
# 1256 / 2492
# Saving 1256 To Output
# 1257 / 2492
# Saving 1257 To Output
# 1258 / 2492
# Saving 1258 To Output
# 1259 / 2492
# Saving 1259 To Output
# 1260 / 2492
# Saving 1260 To Output
# 1261 / 2492
# Saving 1261 To Output
# 1262 / 2492
# 1263 / 2492
# Saving 1263 To Output
# 1264 / 2492
# Saving 1264 To Output
# 1265 / 2492
# 1266 / 2492
# 1267 / 2492
# Saving 1267 To Output
# 1268 / 2492
# 1269 / 2492
# Saving 1269 To Output
# 1270 / 2492
# Saving 1270 To Output
# 1271 / 2492
# Saving 1271 To Output
# 1272 / 2492
# 1273 / 2492
# Saving 1273 To Output
# 1274 / 2492
# Saving 1274 To Output
# 1275 / 2492
# 1276 / 2492
# Saving 1276 To Output
# 1277 / 2492
# 1278 / 2492
# Saving 1278 To Output
# 1279 / 2492
# 1280 / 2492
# 1281 / 2492
# Saving 1281 To Output
# 1282 / 2492
# 1283 / 2492
# Saving 1283 To Output
# 1284 / 2492
# 1285 / 2492
# Saving 1285 To Output
# 1286 / 2492
# 1287 / 2492
# Saving 1287 To Output
# 1288 / 2492
# 1289 / 2492
# 1290 / 2492
# 1291 / 2492
# 1292 / 2492
# 1293 / 2492
# 1294 / 2492
# Saving 1294 To Output
# 1295 / 2492
# 1296 / 2492
# Saving 1296 To Output
# 1297 / 2492
# Saving 1297 To Output
# 1298 / 2492
# Saving 1298 To Output
# 1299 / 2492
# Saving 1299 To Output
# 1300 / 2492
# Saving 1300 To Output
# 1301 / 2492
# 1302 / 2492
# Saving 1302 To Output
# 1303 / 2492
# Saving 1303 To Output
# 1304 / 2492
# 1305 / 2492
# Saving 1305 To Output
# 1306 / 2492
# Saving 1306 To Output
# 1307 / 2492
# 1308 / 2492
# 1309 / 2492
# 1310 / 2492
# Saving 1310 To Output
# 1311 / 2492
# Saving 1311 To Output
# 1312 / 2492
# Saving 1312 To Output
# 1313 / 2492
# Saving 1313 To Output
# 1314 / 2492
# 1315 / 2492
# Saving 1315 To Output
# 1316 / 2492
# Saving 1316 To Output
# 1317 / 2492
# Saving 1317 To Output
# 1318 / 2492
# 1319 / 2492
# 1320 / 2492
# 1321 / 2492
# 1322 / 2492
# Saving 1322 To Output
# 1323 / 2492
# Saving 1323 To Output
# 1324 / 2492
# 1325 / 2492
# 1326 / 2492
# 1327 / 2492
# 1328 / 2492
# 1329 / 2492
# 1330 / 2492
# Saving 1330 To Output
# 1331 / 2492
# 1332 / 2492
# Saving 1332 To Output
# 1333 / 2492
# Saving 1333 To Output
# 1334 / 2492
# 1335 / 2492
# 1336 / 2492
# 1337 / 2492
# Saving 1337 To Output
# 1338 / 2492
# 1339 / 2492
# 1340 / 2492
# Saving 1340 To Output
# 1341 / 2492
# Saving 1341 To Output
# 1342 / 2492
# 1343 / 2492
# 1344 / 2492
# Saving 1344 To Output
# 1345 / 2492
# Saving 1345 To Output
# 1346 / 2492
# 1347 / 2492
# 1348 / 2492
# Saving 1348 To Output
# 1349 / 2492
# 1350 / 2492
# 1351 / 2492
# Saving 1351 To Output
# 1352 / 2492
# Saving 1352 To Output
# 1353 / 2492
# 1354 / 2492
# Saving 1354 To Output
# 1355 / 2492
# Saving 1355 To Output
# 1356 / 2492
# 1357 / 2492
# 1358 / 2492
# Saving 1358 To Output
# 1359 / 2492
# Saving 1359 To Output
# 1360 / 2492
# 1361 / 2492
# Saving 1361 To Output
# 1362 / 2492
# Saving 1362 To Output
# 1363 / 2492
# Saving 1363 To Output
# 1364 / 2492
# Saving 1364 To Output
# 1365 / 2492
# 1366 / 2492
# 1367 / 2492
# Saving 1367 To Output
# 1368 / 2492
# 1369 / 2492
# Saving 1369 To Output
# 1370 / 2492
# Saving 1370 To Output
# 1371 / 2492
# Saving 1371 To Output
# 1372 / 2492
# 1373 / 2492
# Saving 1373 To Output
# 1374 / 2492
# 1375 / 2492
# 1376 / 2492
# Saving 1376 To Output
# 1377 / 2492
# Saving 1377 To Output
# 1378 / 2492
# Saving 1378 To Output
# 1379 / 2492
# 1380 / 2492
# 1381 / 2492
# 1382 / 2492
# Saving 1382 To Output
# 1383 / 2492
# Saving 1383 To Output
# 1384 / 2492
# 1385 / 2492
# Saving 1385 To Output
# 1386 / 2492
# Saving 1386 To Output
# 1387 / 2492
# 1388 / 2492
# Saving 1388 To Output
# 1389 / 2492
# 1390 / 2492
# 1391 / 2492
# 1392 / 2492
# 1393 / 2492
# Saving 1393 To Output
# 1394 / 2492
# 1395 / 2492
# 1396 / 2492
# 1397 / 2492
# 1398 / 2492
# Saving 1398 To Output
# 1399 / 2492
# Saving 1399 To Output
# 1400 / 2492
# 1401 / 2492
# Saving 1401 To Output
# 1402 / 2492
# 1403 / 2492
# 1404 / 2492
# Saving 1404 To Output
# 1405 / 2492
# 1406 / 2492
# Saving 1406 To Output
# 1407 / 2492
# 1408 / 2492
# Saving 1408 To Output
# 1409 / 2492
# Saving 1409 To Output
# 1410 / 2492
# 1411 / 2492
# Saving 1411 To Output
# 1412 / 2492
# 1413 / 2492
# Saving 1413 To Output
# 1414 / 2492
# Saving 1414 To Output
# 1415 / 2492
# 1416 / 2492
# Saving 1416 To Output
# 1417 / 2492
# Saving 1417 To Output
# 1418 / 2492
# Saving 1418 To Output
# 1419 / 2492
# 1420 / 2492
# Saving 1420 To Output
# 1421 / 2492
# Saving 1421 To Output
# 1422 / 2492
# Saving 1422 To Output
# 1423 / 2492
# 1424 / 2492
# Saving 1424 To Output
# 1425 / 2492
# Saving 1425 To Output
# 1426 / 2492
# 1427 / 2492
# Saving 1427 To Output
# 1428 / 2492
# Saving 1428 To Output
# 1429 / 2492
# Saving 1429 To Output
# 1430 / 2492
# 1431 / 2492
# 1432 / 2492
# Saving 1432 To Output
# 1433 / 2492
# Saving 1433 To Output
# 1434 / 2492
# Saving 1434 To Output
# 1435 / 2492
# Saving 1435 To Output
# 1436 / 2492
# 1437 / 2492
# Saving 1437 To Output
# 1438 / 2492
# Saving 1438 To Output
# 1439 / 2492
# 1440 / 2492
# 1441 / 2492
# 1442 / 2492
# Saving 1442 To Output
# 1443 / 2492
# Saving 1443 To Output
# 1444 / 2492
# Saving 1444 To Output
# 1445 / 2492
# 1446 / 2492
# 1447 / 2492
# 1448 / 2492
# 1449 / 2492
# 1450 / 2492
# Saving 1450 To Output
# 1451 / 2492
# 1452 / 2492
# Saving 1452 To Output
# 1453 / 2492
# Saving 1453 To Output
# 1454 / 2492
# Saving 1454 To Output
# 1455 / 2492
# Saving 1455 To Output
# 1456 / 2492
# Saving 1456 To Output
# 1457 / 2492
# Saving 1457 To Output
# 1458 / 2492
# Saving 1458 To Output
# 1459 / 2492
# 1460 / 2492
# 1461 / 2492
# Saving 1461 To Output
# 1462 / 2492
# Saving 1462 To Output
# 1463 / 2492
# Saving 1463 To Output
# 1464 / 2492
# Saving 1464 To Output
# 1465 / 2492
# Saving 1465 To Output
# 1466 / 2492
# Saving 1466 To Output
# 1467 / 2492
# Saving 1467 To Output
# 1468 / 2492
# 1469 / 2492
# 1470 / 2492
# Saving 1470 To Output
# 1471 / 2492
# 1472 / 2492
# 1473 / 2492
# Saving 1473 To Output
# 1474 / 2492
# Saving 1474 To Output
# 1475 / 2492
# Saving 1475 To Output
# 1476 / 2492
# 1477 / 2492
# Saving 1477 To Output
# 1478 / 2492
# Saving 1478 To Output
# 1479 / 2492
# 1480 / 2492
# Saving 1480 To Output
# 1481 / 2492
# 1482 / 2492
# 1483 / 2492
# 1484 / 2492
# 1485 / 2492
# Saving 1485 To Output
# 1486 / 2492
# Saving 1486 To Output
# 1487 / 2492
# Saving 1487 To Output
# 1488 / 2492
# 1489 / 2492
# 1490 / 2492
# 1491 / 2492
# Saving 1491 To Output
# 1492 / 2492
# 1493 / 2492
# 1494 / 2492
# Saving 1494 To Output
# 1495 / 2492
# Saving 1495 To Output
# 1496 / 2492
# Saving 1496 To Output
# 1497 / 2492
# Saving 1497 To Output
# 1498 / 2492
# Saving 1498 To Output
# 1499 / 2492
# Saving 1499 To Output
# 1500 / 2492
# Saving 1500 To Output
# 1501 / 2492
# Saving 1501 To Output
# 1502 / 2492
# Saving 1502 To Output
# 1503 / 2492
# 1504 / 2492
# 1505 / 2492
# Saving 1505 To Output
# 1506 / 2492
# Saving 1506 To Output
# 1507 / 2492
# Saving 1507 To Output
# 1508 / 2492
# Saving 1508 To Output
# 1509 / 2492
# 1510 / 2492
# Saving 1510 To Output
# 1511 / 2492
# 1512 / 2492
# Saving 1512 To Output
# 1513 / 2492
# Saving 1513 To Output
# 1514 / 2492
# 1515 / 2492
# Saving 1515 To Output
# 1516 / 2492
# Saving 1516 To Output
# 1517 / 2492
# 1518 / 2492
# Saving 1518 To Output
# 1519 / 2492
# 1520 / 2492
# 1521 / 2492
# Saving 1521 To Output
# 1522 / 2492
# Saving 1522 To Output
# 1523 / 2492
# Saving 1523 To Output
# 1524 / 2492
# Saving 1524 To Output
# 1525 / 2492
# Saving 1525 To Output
# 1526 / 2492
# 1527 / 2492
# Saving 1527 To Output
# 1528 / 2492
# Saving 1528 To Output
# 1529 / 2492
# Saving 1529 To Output
# 1530 / 2492
# 1531 / 2492
# 1532 / 2492
# Saving 1532 To Output
# 1533 / 2492
# Saving 1533 To Output
# 1534 / 2492
# Saving 1534 To Output
# 1535 / 2492
# Saving 1535 To Output
# 1536 / 2492
# Saving 1536 To Output
# 1537 / 2492
# 1538 / 2492
# 1539 / 2492
# 1540 / 2492
# Saving 1540 To Output
# 1541 / 2492
# Saving 1541 To Output
# 1542 / 2492
# Saving 1542 To Output
# 1543 / 2492
# Saving 1543 To Output
# 1544 / 2492
# Saving 1544 To Output
# 1545 / 2492
# Saving 1545 To Output
# 1546 / 2492
# Saving 1546 To Output
# 1547 / 2492
# Saving 1547 To Output
# 1548 / 2492
# Saving 1548 To Output
# 1549 / 2492
# Saving 1549 To Output
# 1550 / 2492
# Saving 1550 To Output
# 1551 / 2492
# 1552 / 2492
# 1553 / 2492
# Saving 1553 To Output
# 1554 / 2492
# 1555 / 2492
# 1556 / 2492
# 1557 / 2492
# Saving 1557 To Output
# 1558 / 2492
# Saving 1558 To Output
# 1559 / 2492
# 1560 / 2492
# 1561 / 2492
# 1562 / 2492
# Saving 1562 To Output
# 1563 / 2492
# Saving 1563 To Output
# 1564 / 2492
# Saving 1564 To Output
# 1565 / 2492
# Saving 1565 To Output
# 1566 / 2492
# 1567 / 2492
# 1568 / 2492
# 1569 / 2492
# 1570 / 2492
# 1571 / 2492
# Saving 1571 To Output
# 1572 / 2492
# 1573 / 2492
# Saving 1573 To Output
# 1574 / 2492
# 1575 / 2492
# Saving 1575 To Output
# 1576 / 2492
# Saving 1576 To Output
# 1577 / 2492
# 1578 / 2492
# Saving 1578 To Output
# 1579 / 2492
# 1580 / 2492
# Saving 1580 To Output
# 1581 / 2492
# 1582 / 2492
# 1583 / 2492
# Saving 1583 To Output
# 1584 / 2492
# 1585 / 2492
# Saving 1585 To Output
# 1586 / 2492
# 1587 / 2492
# Saving 1587 To Output
# 1588 / 2492
# 1589 / 2492
# 1590 / 2492
# 1591 / 2492
# Saving 1591 To Output
# 1592 / 2492
# 1593 / 2492
# 1594 / 2492
# Saving 1594 To Output
# 1595 / 2492
# 1596 / 2492
# Saving 1596 To Output
# 1597 / 2492
# 1598 / 2492
# Saving 1598 To Output
# 1599 / 2492
# Saving 1599 To Output
# 1600 / 2492
# Saving 1600 To Output
# 1601 / 2492
# Saving 1601 To Output
# 1602 / 2492
# 1603 / 2492
# Saving 1603 To Output
# 1604 / 2492
# 1605 / 2492
# Saving 1605 To Output
# 1606 / 2492
# 1607 / 2492
# 1608 / 2492
# Saving 1608 To Output
# 1609 / 2492
# 1610 / 2492
# Saving 1610 To Output
# 1611 / 2492
# Saving 1611 To Output
# 1612 / 2492
# Saving 1612 To Output
# 1613 / 2492
# 1614 / 2492
# Saving 1614 To Output
# 1615 / 2492
# Saving 1615 To Output
# 1616 / 2492
# 1617 / 2492
# 1618 / 2492
# Saving 1618 To Output
# 1619 / 2492
# Saving 1619 To Output
# 1620 / 2492
# Saving 1620 To Output
# 1621 / 2492
# Saving 1621 To Output
# 1622 / 2492
# Saving 1622 To Output
# 1623 / 2492
# 1624 / 2492
# Saving 1624 To Output
# 1625 / 2492
# 1626 / 2492
# Saving 1626 To Output
# 1627 / 2492
# 1628 / 2492
# Saving 1628 To Output
# 1629 / 2492
# Saving 1629 To Output
# 1630 / 2492
# 1631 / 2492
# 1632 / 2492
# Saving 1632 To Output
# 1633 / 2492
# Saving 1633 To Output
# 1634 / 2492
# 1635 / 2492
# Saving 1635 To Output
# 1636 / 2492
# Saving 1636 To Output
# 1637 / 2492
# Saving 1637 To Output
# 1638 / 2492
# 1639 / 2492
# 1640 / 2492
# 1641 / 2492
# Saving 1641 To Output
# 1642 / 2492
# Saving 1642 To Output
# 1643 / 2492
# Saving 1643 To Output
# 1644 / 2492
# Saving 1644 To Output
# 1645 / 2492
# Saving 1645 To Output
# 1646 / 2492
# Saving 1646 To Output
# 1647 / 2492
# Saving 1647 To Output
# 1648 / 2492
# 1649 / 2492
# 1650 / 2492
# Saving 1650 To Output
# 1651 / 2492
# 1652 / 2492
# Saving 1652 To Output
# 1653 / 2492
# 1654 / 2492
# Saving 1654 To Output
# 1655 / 2492
# Saving 1655 To Output
# 1656 / 2492
# Saving 1656 To Output
# 1657 / 2492
# Saving 1657 To Output
# 1658 / 2492
# 1659 / 2492
# Saving 1659 To Output
# 1660 / 2492
# 1661 / 2492
# Saving 1661 To Output
# 1662 / 2492
# 1663 / 2492
# 1664 / 2492
# Saving 1664 To Output
# 1665 / 2492
# 1666 / 2492
# 1667 / 2492
# 1668 / 2492
# Saving 1668 To Output
# 1669 / 2492
# 1670 / 2492
# Saving 1670 To Output
# 1671 / 2492
# Saving 1671 To Output
# 1672 / 2492
# Saving 1672 To Output
# 1673 / 2492
# Saving 1673 To Output
# 1674 / 2492
# 1675 / 2492
# 1676 / 2492
# Saving 1676 To Output
# 1677 / 2492
# Saving 1677 To Output
# 1678 / 2492
# Saving 1678 To Output
# 1679 / 2492
# 1680 / 2492
# 1681 / 2492
# Saving 1681 To Output
# 1682 / 2492
# Saving 1682 To Output
# 1683 / 2492
# Saving 1683 To Output
# 1684 / 2492
# 1685 / 2492
# 1686 / 2492
# Saving 1686 To Output
# 1687 / 2492
# 1688 / 2492
# Saving 1688 To Output
# 1689 / 2492
# 1690 / 2492
# 1691 / 2492
# Saving 1691 To Output
# 1692 / 2492
# 1693 / 2492
# 1694 / 2492
# 1695 / 2492
# 1696 / 2492
# Saving 1696 To Output
# 1697 / 2492
# Saving 1697 To Output
# 1698 / 2492
# 1699 / 2492
# Saving 1699 To Output
# 1700 / 2492
# Saving 1700 To Output
# 1701 / 2492
# 1702 / 2492
# Saving 1702 To Output
# 1703 / 2492
# Saving 1703 To Output
# 1704 / 2492
# Saving 1704 To Output
# 1705 / 2492
# 1706 / 2492
# Saving 1706 To Output
# 1707 / 2492
# Saving 1707 To Output
# 1708 / 2492
# Saving 1708 To Output
# 1709 / 2492
# Saving 1709 To Output
# 1710 / 2492
# 1711 / 2492
# Saving 1711 To Output
# 1712 / 2492
# Saving 1712 To Output
# 1713 / 2492
# Saving 1713 To Output
# 1714 / 2492
# Saving 1714 To Output
# 1715 / 2492
# Saving 1715 To Output
# 1716 / 2492
# Saving 1716 To Output
# 1717 / 2492
# Saving 1717 To Output
# 1718 / 2492
# Saving 1718 To Output
# 1719 / 2492
# Saving 1719 To Output
# 1720 / 2492
# 1721 / 2492
# 1722 / 2492
# Saving 1722 To Output
# 1723 / 2492
# Saving 1723 To Output
# 1724 / 2492
# 1725 / 2492
# Saving 1725 To Output
# 1726 / 2492
# Saving 1726 To Output
# 1727 / 2492
# 1728 / 2492
# Saving 1728 To Output
# 1729 / 2492
# Saving 1729 To Output
# 1730 / 2492
# Saving 1730 To Output
# 1731 / 2492
# 1732 / 2492
# Saving 1732 To Output
# 1733 / 2492
# 1734 / 2492
# Saving 1734 To Output
# 1735 / 2492
# Saving 1735 To Output
# 1736 / 2492
# Saving 1736 To Output
# 1737 / 2492
# 1738 / 2492
# 1739 / 2492
# 1740 / 2492
# 1741 / 2492
# 1742 / 2492
# Saving 1742 To Output
# 1743 / 2492
# 1744 / 2492
# Saving 1744 To Output
# 1745 / 2492
# Saving 1745 To Output
# 1746 / 2492
# 1747 / 2492
# Saving 1747 To Output
# 1748 / 2492
# 1749 / 2492
# Saving 1749 To Output
# 1750 / 2492
# Saving 1750 To Output
# 1751 / 2492
# 1752 / 2492
# Saving 1752 To Output
# 1753 / 2492
# Saving 1753 To Output
# 1754 / 2492
# Saving 1754 To Output
# 1755 / 2492
# Saving 1755 To Output
# 1756 / 2492
# Saving 1756 To Output
# 1757 / 2492
# Saving 1757 To Output
# 1758 / 2492
# 1759 / 2492
# 1760 / 2492
# Saving 1760 To Output
# 1761 / 2492
# Saving 1761 To Output
# 1762 / 2492
# Saving 1762 To Output
# 1763 / 2492
# 1764 / 2492
# Saving 1764 To Output
# 1765 / 2492
# Saving 1765 To Output
# 1766 / 2492
# Saving 1766 To Output
# 1767 / 2492
# Saving 1767 To Output
# 1768 / 2492
# Saving 1768 To Output
# 1769 / 2492
# Saving 1769 To Output
# 1770 / 2492
# 1771 / 2492
# Saving 1771 To Output
# 1772 / 2492
# Saving 1772 To Output
# 1773 / 2492
# 1774 / 2492
# 1775 / 2492
# Saving 1775 To Output
# 1776 / 2492
# 1777 / 2492
# Saving 1777 To Output
# 1778 / 2492
# 1779 / 2492
# 1780 / 2492
# Saving 1780 To Output
# 1781 / 2492
# Saving 1781 To Output
# 1782 / 2492
# 1783 / 2492
# 1784 / 2492
# 1785 / 2492
# Saving 1785 To Output
# 1786 / 2492
# Saving 1786 To Output
# 1787 / 2492
# 1788 / 2492
# Saving 1788 To Output
# 1789 / 2492
# Saving 1789 To Output
# 1790 / 2492
# Saving 1790 To Output
# 1791 / 2492
# Saving 1791 To Output
# 1792 / 2492
# Saving 1792 To Output
# 1793 / 2492
# Saving 1793 To Output
# 1794 / 2492
# Saving 1794 To Output
# 1795 / 2492
# 1796 / 2492
# 1797 / 2492
# 1798 / 2492
# Saving 1798 To Output
# 1799 / 2492
# 1800 / 2492
# 1801 / 2492
# 1802 / 2492
# Saving 1802 To Output
# 1803 / 2492
# 1804 / 2492
# Saving 1804 To Output
# 1805 / 2492
# Saving 1805 To Output
# 1806 / 2492
# 1807 / 2492
# 1808 / 2492
# 1809 / 2492
# 1810 / 2492
# 1811 / 2492
# Saving 1811 To Output
# 1812 / 2492
# 1813 / 2492
# Saving 1813 To Output
# 1814 / 2492
# 1815 / 2492
# Saving 1815 To Output
# 1816 / 2492
# 1817 / 2492
# 1818 / 2492
# Saving 1818 To Output
# 1819 / 2492
# 1820 / 2492
# 1821 / 2492
# 1822 / 2492
# 1823 / 2492
# Saving 1823 To Output
# 1824 / 2492
# Saving 1824 To Output
# 1825 / 2492
# 1826 / 2492
# Saving 1826 To Output
# 1827 / 2492
# 1828 / 2492
# 1829 / 2492
# Saving 1829 To Output
# 1830 / 2492
# 1831 / 2492
# Saving 1831 To Output
# 1832 / 2492
# Saving 1832 To Output
# 1833 / 2492
# 1834 / 2492
# Saving 1834 To Output
# 1835 / 2492
# Saving 1835 To Output
# 1836 / 2492
# 1837 / 2492
# 1838 / 2492
# Saving 1838 To Output
# 1839 / 2492
# Saving 1839 To Output
# 1840 / 2492
# 1841 / 2492
# Saving 1841 To Output
# 1842 / 2492
# 1843 / 2492
# Saving 1843 To Output
# 1844 / 2492
# 1845 / 2492
# 1846 / 2492
# Saving 1846 To Output
# 1847 / 2492
# Saving 1847 To Output
# 1848 / 2492
# Saving 1848 To Output
# 1849 / 2492
# Saving 1849 To Output
# 1850 / 2492
# Saving 1850 To Output
# 1851 / 2492
# 1852 / 2492
# 1853 / 2492
# Saving 1853 To Output
# 1854 / 2492
# Saving 1854 To Output
# 1855 / 2492
# Saving 1855 To Output
# 1856 / 2492
# 1857 / 2492
# 1858 / 2492
# 1859 / 2492
# Saving 1859 To Output
# 1860 / 2492
# 1861 / 2492
# Saving 1861 To Output
# 1862 / 2492
# Saving 1862 To Output
# 1863 / 2492
# Saving 1863 To Output
# 1864 / 2492
# 1865 / 2492
# Saving 1865 To Output
# 1866 / 2492
# Saving 1866 To Output
# 1867 / 2492
# 1868 / 2492
# Saving 1868 To Output
# 1869 / 2492
# 1870 / 2492
# Saving 1870 To Output
# 1871 / 2492
# Saving 1871 To Output
# 1872 / 2492
# Saving 1872 To Output
# 1873 / 2492
# Saving 1873 To Output
# 1874 / 2492
# Saving 1874 To Output
# 1875 / 2492
# Saving 1875 To Output
# 1876 / 2492
# Saving 1876 To Output
# 1877 / 2492
# 1878 / 2492
# Saving 1878 To Output
# 1879 / 2492
# 1880 / 2492
# Saving 1880 To Output
# 1881 / 2492
# Saving 1881 To Output
# 1882 / 2492
# Saving 1882 To Output
# 1883 / 2492
# Saving 1883 To Output
# 1884 / 2492
# Saving 1884 To Output
# 1885 / 2492
# 1886 / 2492
# Saving 1886 To Output
# 1887 / 2492
# Saving 1887 To Output
# 1888 / 2492
# Saving 1888 To Output
# 1889 / 2492
# Saving 1889 To Output
# 1890 / 2492
# 1891 / 2492
# 1892 / 2492
# Saving 1892 To Output
# 1893 / 2492
# Saving 1893 To Output
# 1894 / 2492
# Saving 1894 To Output
# 1895 / 2492
# 1896 / 2492
# Saving 1896 To Output
# 1897 / 2492
# 1898 / 2492
# Saving 1898 To Output
# 1899 / 2492
# Saving 1899 To Output
# 1900 / 2492
# 1901 / 2492
# Saving 1901 To Output
# 1902 / 2492
# 1903 / 2492
# Saving 1903 To Output
# 1904 / 2492
# 1905 / 2492
# 1906 / 2492
# Saving 1906 To Output
# 1907 / 2492
# 1908 / 2492
# Saving 1908 To Output
# 1909 / 2492
# Saving 1909 To Output
# 1910 / 2492
# 1911 / 2492
# Saving 1911 To Output
# 1912 / 2492
# Saving 1912 To Output
# 1913 / 2492
# Saving 1913 To Output
# 1914 / 2492
# 1915 / 2492
# Saving 1915 To Output
# 1916 / 2492
# 1917 / 2492
# Saving 1917 To Output
# 1918 / 2492
# Saving 1918 To Output
# 1919 / 2492
# 1920 / 2492
# Saving 1920 To Output
# 1921 / 2492
# Saving 1921 To Output
# 1922 / 2492
# Saving 1922 To Output
# 1923 / 2492
# Saving 1923 To Output
# 1924 / 2492
# 1925 / 2492
# Saving 1925 To Output
# 1926 / 2492
# 1927 / 2492
# Saving 1927 To Output
# 1928 / 2492
# 1929 / 2492
# 1930 / 2492
# 1931 / 2492
# Saving 1931 To Output
# 1932 / 2492
# Saving 1932 To Output
# 1933 / 2492
# Saving 1933 To Output
# 1934 / 2492
# 1935 / 2492
# Saving 1935 To Output
# 1936 / 2492
# 1937 / 2492
# Saving 1937 To Output
# 1938 / 2492
# 1939 / 2492
# Saving 1939 To Output
# 1940 / 2492
# Saving 1940 To Output
# 1941 / 2492
# Saving 1941 To Output
# 1942 / 2492
# 1943 / 2492
# Saving 1943 To Output
# 1944 / 2492
# Saving 1944 To Output
# 1945 / 2492
# Saving 1945 To Output
# 1946 / 2492
# Saving 1946 To Output
# 1947 / 2492
# Saving 1947 To Output
# 1948 / 2492
# 1949 / 2492
# Saving 1949 To Output
# 1950 / 2492
# 1951 / 2492
# Saving 1951 To Output
# 1952 / 2492
# Saving 1952 To Output
# 1953 / 2492
# 1954 / 2492
# 1955 / 2492
# Saving 1955 To Output
# 1956 / 2492
# Saving 1956 To Output
# 1957 / 2492
# Saving 1957 To Output
# 1958 / 2492
# Saving 1958 To Output
# 1959 / 2492
# Saving 1959 To Output
# 1960 / 2492
# Saving 1960 To Output
# 1961 / 2492
# Saving 1961 To Output
# 1962 / 2492
# Saving 1962 To Output
# 1963 / 2492
# 1964 / 2492
# Saving 1964 To Output
# 1965 / 2492
# 1966 / 2492
# 1967 / 2492
# Saving 1967 To Output
# 1968 / 2492
# 1969 / 2492
# Saving 1969 To Output
# 1970 / 2492
# Saving 1970 To Output
# 1971 / 2492
# Saving 1971 To Output
# 1972 / 2492
# Saving 1972 To Output
# 1973 / 2492
# Saving 1973 To Output
# 1974 / 2492
# 1975 / 2492
# Saving 1975 To Output
# 1976 / 2492
# Saving 1976 To Output
# 1977 / 2492
# 1978 / 2492
# Saving 1978 To Output
# 1979 / 2492
# 1980 / 2492
# 1981 / 2492
# Saving 1981 To Output
# 1982 / 2492
# 1983 / 2492
# 1984 / 2492
# Saving 1984 To Output
# 1985 / 2492
# Saving 1985 To Output
# 1986 / 2492
# 1987 / 2492
# Saving 1987 To Output
# 1988 / 2492
# Saving 1988 To Output
# 1989 / 2492
# Saving 1989 To Output
# 1990 / 2492
# 1991 / 2492
# Saving 1991 To Output
# 1992 / 2492
# Saving 1992 To Output
# 1993 / 2492
# Saving 1993 To Output
# 1994 / 2492
# 1995 / 2492
# 1996 / 2492
# Saving 1996 To Output
# 1997 / 2492
# 1998 / 2492
# 1999 / 2492
# Saving 1999 To Output
# 2000 / 2492
# 2001 / 2492
# 2002 / 2492
# 2003 / 2492
# Saving 2003 To Output
# 2004 / 2492
# Saving 2004 To Output
# 2005 / 2492
# 2006 / 2492
# Saving 2006 To Output
# 2007 / 2492
# Saving 2007 To Output
# 2008 / 2492
# Saving 2008 To Output
# 2009 / 2492
# 2010 / 2492
# 2011 / 2492
# Saving 2011 To Output
# 2012 / 2492
# 2013 / 2492
# 2014 / 2492
# 2015 / 2492
# Saving 2015 To Output
# 2016 / 2492
# 2017 / 2492
# 2018 / 2492
# Saving 2018 To Output
# 2019 / 2492
# Saving 2019 To Output
# 2020 / 2492
# Saving 2020 To Output
# 2021 / 2492
# Saving 2021 To Output
# 2022 / 2492
# Saving 2022 To Output
# 2023 / 2492
# Saving 2023 To Output
# 2024 / 2492
# Saving 2024 To Output
# 2025 / 2492
# 2026 / 2492
# Saving 2026 To Output
# 2027 / 2492
# Saving 2027 To Output
# 2028 / 2492
# 2029 / 2492
# 2030 / 2492
# Saving 2030 To Output
# 2031 / 2492
# 2032 / 2492
# Saving 2032 To Output
# 2033 / 2492
# 2034 / 2492
# 2035 / 2492
# Saving 2035 To Output
# 2036 / 2492
# Saving 2036 To Output
# 2037 / 2492
# Saving 2037 To Output
# 2038 / 2492
# Saving 2038 To Output
# 2039 / 2492
# Saving 2039 To Output
# 2040 / 2492
# 2041 / 2492
# Saving 2041 To Output
# 2042 / 2492
# 2043 / 2492
# Saving 2043 To Output
# 2044 / 2492
# Saving 2044 To Output
# 2045 / 2492
# Saving 2045 To Output
# 2046 / 2492
# 2047 / 2492
# 2048 / 2492
# Saving 2048 To Output
# 2049 / 2492
# Saving 2049 To Output
# 2050 / 2492
# 2051 / 2492
# Saving 2051 To Output
# 2052 / 2492
# 2053 / 2492
# 2054 / 2492
# 2055 / 2492
# Saving 2055 To Output
# 2056 / 2492
# 2057 / 2492
# Saving 2057 To Output
# 2058 / 2492
# 2059 / 2492
# 2060 / 2492
# Saving 2060 To Output
# 2061 / 2492
# Saving 2061 To Output
# 2062 / 2492
# Saving 2062 To Output
# 2063 / 2492
# Saving 2063 To Output
# 2064 / 2492
# 2065 / 2492
# Saving 2065 To Output
# 2066 / 2492
# Saving 2066 To Output
# 2067 / 2492
# Saving 2067 To Output
# 2068 / 2492
# 2069 / 2492
# Saving 2069 To Output
# 2070 / 2492
# Saving 2070 To Output
# 2071 / 2492
# 2072 / 2492
# Saving 2072 To Output
# 2073 / 2492
# 2074 / 2492
# Saving 2074 To Output
# 2075 / 2492
# Saving 2075 To Output
# 2076 / 2492
# Saving 2076 To Output
# 2077 / 2492
# 2078 / 2492
# Saving 2078 To Output
# 2079 / 2492
# 2080 / 2492
# Saving 2080 To Output
# 2081 / 2492
# 2082 / 2492
# Saving 2082 To Output
# 2083 / 2492
# Saving 2083 To Output
# 2084 / 2492
# 2085 / 2492
# Saving 2085 To Output
# 2086 / 2492
# 2087 / 2492
# Saving 2087 To Output
# 2088 / 2492
# Saving 2088 To Output
# 2089 / 2492
# 2090 / 2492
# 2091 / 2492
# Saving 2091 To Output
# 2092 / 2492
# Saving 2092 To Output
# 2093 / 2492
# Saving 2093 To Output
# 2094 / 2492
# Saving 2094 To Output
# 2095 / 2492
# Saving 2095 To Output
# 2096 / 2492
# Saving 2096 To Output
# 2097 / 2492
# Saving 2097 To Output
# 2098 / 2492
# 2099 / 2492
# 2100 / 2492
# Saving 2100 To Output
# 2101 / 2492
# Saving 2101 To Output
# 2102 / 2492
# Saving 2102 To Output
# 2103 / 2492
# Saving 2103 To Output
# 2104 / 2492
# 2105 / 2492
# Saving 2105 To Output
# 2106 / 2492
# 2107 / 2492
# Saving 2107 To Output
# 2108 / 2492
# 2109 / 2492
# 2110 / 2492
# Saving 2110 To Output
# 2111 / 2492
# Saving 2111 To Output
# 2112 / 2492
# 2113 / 2492
# 2114 / 2492
# 2115 / 2492
# Saving 2115 To Output
# 2116 / 2492
# 2117 / 2492
# 2118 / 2492
# 2119 / 2492
# 2120 / 2492
# Saving 2120 To Output
# 2121 / 2492
# Saving 2121 To Output
# 2122 / 2492
# 2123 / 2492
# 2124 / 2492
# 2125 / 2492
# 2126 / 2492
# Saving 2126 To Output
# 2127 / 2492
# Saving 2127 To Output
# 2128 / 2492
# 2129 / 2492
# Saving 2129 To Output
# 2130 / 2492
# Saving 2130 To Output
# 2131 / 2492
# 2132 / 2492
# Saving 2132 To Output
# 2133 / 2492
# 2134 / 2492
# Saving 2134 To Output
# 2135 / 2492
# 2136 / 2492
# 2137 / 2492
# 2138 / 2492
# Saving 2138 To Output
# 2139 / 2492
# 2140 / 2492
# Saving 2140 To Output
# 2141 / 2492
# Saving 2141 To Output
# 2142 / 2492
# Saving 2142 To Output
# 2143 / 2492
# 2144 / 2492
# Saving 2144 To Output
# 2145 / 2492
# Saving 2145 To Output
# 2146 / 2492
# 2147 / 2492
# Saving 2147 To Output
# 2148 / 2492
# Saving 2148 To Output
# 2149 / 2492
# Saving 2149 To Output
# 2150 / 2492
# Saving 2150 To Output
# 2151 / 2492
# 2152 / 2492
# 2153 / 2492
# 2154 / 2492
# 2155 / 2492
# 2156 / 2492
# 2157 / 2492
# Saving 2157 To Output
# 2158 / 2492
# Saving 2158 To Output
# 2159 / 2492
# Saving 2159 To Output
# 2160 / 2492
# 2161 / 2492
# 2162 / 2492
# Saving 2162 To Output
# 2163 / 2492
# 2164 / 2492
# Saving 2164 To Output
# 2165 / 2492
# Saving 2165 To Output
# 2166 / 2492
# 2167 / 2492
# Saving 2167 To Output
# 2168 / 2492
# Saving 2168 To Output
# 2169 / 2492
# 2170 / 2492
# Saving 2170 To Output
# 2171 / 2492
# 2172 / 2492
# Saving 2172 To Output
# 2173 / 2492
# Saving 2173 To Output
# 2174 / 2492
# Saving 2174 To Output
# 2175 / 2492
# Saving 2175 To Output
# 2176 / 2492
# Saving 2176 To Output
# 2177 / 2492
# 2178 / 2492
# 2179 / 2492
# Saving 2179 To Output
# 2180 / 2492
# Saving 2180 To Output
# 2181 / 2492
# Saving 2181 To Output
# 2182 / 2492
# Saving 2182 To Output
# 2183 / 2492
# Saving 2183 To Output
# 2184 / 2492
# Saving 2184 To Output
# 2185 / 2492
# 2186 / 2492
# Saving 2186 To Output
# 2187 / 2492
# Saving 2187 To Output
# 2188 / 2492
# 2189 / 2492
# Saving 2189 To Output
# 2190 / 2492
# Saving 2190 To Output
# 2191 / 2492
# 2192 / 2492
# 2193 / 2492
# Saving 2193 To Output
# 2194 / 2492
# Saving 2194 To Output
# 2195 / 2492
# Saving 2195 To Output
# 2196 / 2492
# Saving 2196 To Output
# 2197 / 2492
# Saving 2197 To Output
# 2198 / 2492
# Saving 2198 To Output
# 2199 / 2492
# 2200 / 2492
# 2201 / 2492
# 2202 / 2492
# 2203 / 2492
# Saving 2203 To Output
# 2204 / 2492
# Saving 2204 To Output
# 2205 / 2492
# Saving 2205 To Output
# 2206 / 2492
# Saving 2206 To Output
# 2207 / 2492
# Saving 2207 To Output
# 2208 / 2492
# Saving 2208 To Output
# 2209 / 2492
# Saving 2209 To Output
# 2210 / 2492
# Saving 2210 To Output
# 2211 / 2492
# 2212 / 2492
# 2213 / 2492
# Saving 2213 To Output
# 2214 / 2492
# Saving 2214 To Output
# 2215 / 2492
# Saving 2215 To Output
# 2216 / 2492
# 2217 / 2492
# Saving 2217 To Output
# 2218 / 2492
# 2219 / 2492
# 2220 / 2492
# 2221 / 2492
# Saving 2221 To Output
# 2222 / 2492
# Saving 2222 To Output
# 2223 / 2492
# Saving 2223 To Output
# 2224 / 2492
# 2225 / 2492
# Saving 2225 To Output
# 2226 / 2492
# 2227 / 2492
# 2228 / 2492
# Saving 2228 To Output
# 2229 / 2492
# 2230 / 2492
# Saving 2230 To Output
# 2231 / 2492
# Saving 2231 To Output
# 2232 / 2492
# Saving 2232 To Output
# 2233 / 2492
# Saving 2233 To Output
# 2234 / 2492
# Saving 2234 To Output
# 2235 / 2492
# 2236 / 2492
# Saving 2236 To Output
# 2237 / 2492
# Saving 2237 To Output
# 2238 / 2492
# Saving 2238 To Output
# 2239 / 2492
# 2240 / 2492
# Saving 2240 To Output
# 2241 / 2492
# Saving 2241 To Output
# 2242 / 2492
# Saving 2242 To Output
# 2243 / 2492
# 2244 / 2492
# 2245 / 2492
# Saving 2245 To Output
# 2246 / 2492
# Saving 2246 To Output
# 2247 / 2492
# Saving 2247 To Output
# 2248 / 2492
# Saving 2248 To Output
# 2249 / 2492
# Saving 2249 To Output
# 2250 / 2492
# Saving 2250 To Output
# 2251 / 2492
# 2252 / 2492
# Saving 2252 To Output
# 2253 / 2492
# 2254 / 2492
# 2255 / 2492
# Saving 2255 To Output
# 2256 / 2492
# Saving 2256 To Output
# 2257 / 2492
# 2258 / 2492
# 2259 / 2492
# 2260 / 2492
# Saving 2260 To Output
# 2261 / 2492
# Saving 2261 To Output
# 2262 / 2492
# Saving 2262 To Output
# 2263 / 2492
# 2264 / 2492
# Saving 2264 To Output
# 2265 / 2492
# Saving 2265 To Output
# 2266 / 2492
# 2267 / 2492
# Saving 2267 To Output
# 2268 / 2492
# Saving 2268 To Output
# 2269 / 2492
# 2270 / 2492
# 2271 / 2492
# Saving 2271 To Output
# 2272 / 2492
# Saving 2272 To Output
# 2273 / 2492
# 2274 / 2492
# 2275 / 2492
# Saving 2275 To Output
# 2276 / 2492
# 2277 / 2492
# Saving 2277 To Output
# 2278 / 2492
# 2279 / 2492
# Saving 2279 To Output
# 2280 / 2492
# Saving 2280 To Output
# 2281 / 2492
# Saving 2281 To Output
# 2282 / 2492
# Saving 2282 To Output
# 2283 / 2492
# 2284 / 2492
# Saving 2284 To Output
# 2285 / 2492
# Saving 2285 To Output
# 2286 / 2492
# Saving 2286 To Output
# 2287 / 2492
# 2288 / 2492
# Saving 2288 To Output
# 2289 / 2492
# Saving 2289 To Output
# 2290 / 2492
# 2291 / 2492
# Saving 2291 To Output
# 2292 / 2492
# Saving 2292 To Output
# 2293 / 2492
# 2294 / 2492
# 2295 / 2492
# Saving 2295 To Output
# 2296 / 2492
# Saving 2296 To Output
# 2297 / 2492
# Saving 2297 To Output
# 2298 / 2492
# Saving 2298 To Output
# 2299 / 2492
# 2300 / 2492
# 2301 / 2492
# Saving 2301 To Output
# 2302 / 2492
# Saving 2302 To Output
# 2303 / 2492
# Saving 2303 To Output
# 2304 / 2492
# Saving 2304 To Output
# 2305 / 2492
# 2306 / 2492
# 2307 / 2492
# 2308 / 2492
# Saving 2308 To Output
# 2309 / 2492
# Saving 2309 To Output
# 2310 / 2492
# Saving 2310 To Output
# 2311 / 2492
# 2312 / 2492
# 2313 / 2492
# 2314 / 2492
# Saving 2314 To Output
# 2315 / 2492
# Saving 2315 To Output
# 2316 / 2492
# Saving 2316 To Output
# 2317 / 2492
# 2318 / 2492
# 2319 / 2492
# Saving 2319 To Output
# 2320 / 2492
# Saving 2320 To Output
# 2321 / 2492
# Saving 2321 To Output
# 2322 / 2492
# 2323 / 2492
# Saving 2323 To Output
# 2324 / 2492
# Saving 2324 To Output
# 2325 / 2492
# 2326 / 2492
# 2327 / 2492
# Saving 2327 To Output
# 2328 / 2492
# Saving 2328 To Output
# 2329 / 2492
# Saving 2329 To Output
# 2330 / 2492
# Saving 2330 To Output
# 2331 / 2492
# Saving 2331 To Output
# 2332 / 2492
# 2333 / 2492
# Saving 2333 To Output
# 2334 / 2492
# Saving 2334 To Output
# 2335 / 2492
# 2336 / 2492
# 2337 / 2492
# 2338 / 2492
# Saving 2338 To Output
# 2339 / 2492
# Saving 2339 To Output
# 2340 / 2492
# 2341 / 2492
# Saving 2341 To Output
# 2342 / 2492
# Saving 2342 To Output
# 2343 / 2492
# Saving 2343 To Output
# 2344 / 2492
# Saving 2344 To Output
# 2345 / 2492
# Saving 2345 To Output
# 2346 / 2492
# 2347 / 2492
# Saving 2347 To Output
# 2348 / 2492
# 2349 / 2492
# 2350 / 2492
# Saving 2350 To Output
# 2351 / 2492
# Saving 2351 To Output
# 2352 / 2492
# Saving 2352 To Output
# 2353 / 2492
# Saving 2353 To Output
# 2354 / 2492
# Saving 2354 To Output
# 2355 / 2492
# 2356 / 2492
# Saving 2356 To Output
# 2357 / 2492
# 2358 / 2492
# Saving 2358 To Output
# 2359 / 2492
# 2360 / 2492
# 2361 / 2492
# 2362 / 2492
# Saving 2362 To Output
# 2363 / 2492
# 2364 / 2492
# 2365 / 2492
# 2366 / 2492
# Saving 2366 To Output
# 2367 / 2492
# Saving 2367 To Output
# 2368 / 2492
# 2369 / 2492
# Saving 2369 To Output
# 2370 / 2492
# 2371 / 2492
# Saving 2371 To Output
# 2372 / 2492
# 2373 / 2492
# Saving 2373 To Output
# 2374 / 2492
# 2375 / 2492
# Saving 2375 To Output
# 2376 / 2492
# 2377 / 2492
# 2378 / 2492
# 2379 / 2492
# 2380 / 2492
# 2381 / 2492
# Saving 2381 To Output
# 2382 / 2492
# 2383 / 2492
# Saving 2383 To Output
# 2384 / 2492
# Saving 2384 To Output
# 2385 / 2492
# 2386 / 2492
# 2387 / 2492
# Saving 2387 To Output
# 2388 / 2492
# Saving 2388 To Output
# 2389 / 2492
# Saving 2389 To Output
# 2390 / 2492
# 2391 / 2492
# 2392 / 2492
# Saving 2392 To Output
# 2393 / 2492
# Saving 2393 To Output
# 2394 / 2492
# Saving 2394 To Output
# 2395 / 2492
# Saving 2395 To Output
# 2396 / 2492
# 2397 / 2492
# Saving 2397 To Output
# 2398 / 2492
# Saving 2398 To Output
# 2399 / 2492
# Saving 2399 To Output
# 2400 / 2492
# Saving 2400 To Output
# 2401 / 2492
# Saving 2401 To Output
# 2402 / 2492
# Saving 2402 To Output
# 2403 / 2492
# Saving 2403 To Output
# 2404 / 2492
# Saving 2404 To Output
# 2405 / 2492
# 2406 / 2492
# Saving 2406 To Output
# 2407 / 2492
# Saving 2407 To Output
# 2408 / 2492
# Saving 2408 To Output
# 2409 / 2492
# Saving 2409 To Output
# 2410 / 2492
# Saving 2410 To Output
# 2411 / 2492
# Saving 2411 To Output
# 2412 / 2492
# Saving 2412 To Output
# 2413 / 2492
# Saving 2413 To Output
# 2414 / 2492
# 2415 / 2492
# Saving 2415 To Output
# 2416 / 2492
# 2417 / 2492
# 2418 / 2492
# Saving 2418 To Output
# 2419 / 2492
# 2420 / 2492
# Saving 2420 To Output
# 2421 / 2492
# Saving 2421 To Output
# 2422 / 2492
# Saving 2422 To Output
# 2423 / 2492
# Saving 2423 To Output
# 2424 / 2492
# Saving 2424 To Output
# 2425 / 2492
# 2426 / 2492
# Saving 2426 To Output
# 2427 / 2492
# 2428 / 2492
# Saving 2428 To Output
# 2429 / 2492
# 2430 / 2492
# Saving 2430 To Output
# 2431 / 2492
# 2432 / 2492
# Saving 2432 To Output
# 2433 / 2492
# 2434 / 2492
# 2435 / 2492
# Saving 2435 To Output
# 2436 / 2492
# 2437 / 2492
# Saving 2437 To Output
# 2438 / 2492
# 2439 / 2492
# Saving 2439 To Output
# 2440 / 2492
# Saving 2440 To Output
# 2441 / 2492
# Saving 2441 To Output
# 2442 / 2492
# Saving 2442 To Output
# 2443 / 2492
# 2444 / 2492
# 2445 / 2492
# Saving 2445 To Output
# 2446 / 2492
# Saving 2446 To Output
# 2447 / 2492
# 2448 / 2492
# 2449 / 2492
# 2450 / 2492
# Saving 2450 To Output
# 2451 / 2492
# Saving 2451 To Output
# 2452 / 2492
# Saving 2452 To Output
# 2453 / 2492
# Saving 2453 To Output
# 2454 / 2492
# Saving 2454 To Output
# 2455 / 2492
# 2456 / 2492
# Saving 2456 To Output
# 2457 / 2492
# 2458 / 2492
# Saving 2458 To Output
# 2459 / 2492
# 2460 / 2492
# 2461 / 2492
# Saving 2461 To Output
# 2462 / 2492
# Saving 2462 To Output
# 2463 / 2492
# Saving 2463 To Output
# 2464 / 2492
# Saving 2464 To Output
# 2465 / 2492
# Saving 2465 To Output
# 2466 / 2492
# Saving 2466 To Output
# 2467 / 2492
# 2468 / 2492
# 2469 / 2492
# Saving 2469 To Output
# 2470 / 2492
# 2471 / 2492
# Saving 2471 To Output
# 2472 / 2492
# Saving 2472 To Output
# 2473 / 2492
# Saving 2473 To Output
# 2474 / 2492
# Saving 2474 To Output
# 2475 / 2492
# Saving 2475 To Output
# 2476 / 2492
# 2477 / 2492
# 2478 / 2492
# 2479 / 2492
# 2480 / 2492
# 2481 / 2492
# Saving 2481 To Output
# 2482 / 2492
# Saving 2482 To Output
# 2483 / 2492
# 2484 / 2492
# 2485 / 2492
# 2486 / 2492
# 2487 / 2492
# Saving 2487 To Output
# 2488 / 2492
# 2489 / 2492
# 2490 / 2492
# Saving 2490 To Output
# 2491 / 2492
# Saving 2491 To Output

# %% [markdown]
# ## Creating a violin plot of the data distribution to threshold the feature map

# %% [markdown]
# Finding the min and max of the data

# %%
from sklearn.preprocessing import normalize

# Initialize lists to store the statistics
max_values_correct = []
min_values_correct = []
avg_values_correct = []

max_values_incorrect = []
min_values_incorrect = []
avg_values_incorrect = []

# Iterate through all the predictions
for prediction in loaded_array:
    feature_map, correct_class = prediction[0], int(prediction[1])

    # Flatten the correct class feature map
    flattened_correct = feature_map[:, :, correct_class].flatten()

    # Normalize from 0-1?
    # flattened_correct = normalize(flattened_correct, norm='max', axis=0)

    # Flatten all incorrect class feature maps (excluding the correct class)
    # Removes the correct prediction and flattens all the incorrect classes into a single array
    flattened_incorrect = np.delete(feature_map, correct_class, axis=2).flatten()

    # Normalize from 0-1?
    # flattened_incorrect = normalize(flattened_incorrect, norm='max', axis=0)

    # Calculate and store the statistics for correct class
    max_values_correct.append(np.max(flattened_correct))
    min_values_correct.append(np.min(flattened_correct))
    avg_values_correct.append(np.mean(flattened_correct))

    # Calculate and store the statistics for incorrect classes
    max_values_incorrect.append(np.max(flattened_incorrect))
    min_values_incorrect.append(np.min(flattened_incorrect))
    avg_values_incorrect.append(np.mean(flattened_incorrect))

# Convert lists to NumPy arrays for efficient numerical operations
max_values_correct = np.array(max_values_correct)
min_values_correct = np.array(min_values_correct)
avg_values_correct = np.array(avg_values_correct)

max_values_incorrect = np.array(max_values_incorrect)
min_values_incorrect = np.array(min_values_incorrect)
avg_values_incorrect = np.array(avg_values_incorrect)

# %% [markdown]
# ### Plotting the data

# %%
correctVals = np.concatenate((min_values_correct, max_values_correct, avg_values_correct))
incorrectVals = np.concatenate((min_values_incorrect, max_values_incorrect, avg_values_incorrect))

# Data for plotting
data = [correctVals, incorrectVals]
labels = ['Correct', 'Incorrect']

# Combine the data into one list
data = [correctVals, incorrectVals]

# Calculate means
means = [np.mean(correctVals), np.mean(incorrectVals)]
print(f"Mean values:\n"
      f"Correct Capsule = {means[0]}\n"
      f"Incorrect Capsule = {means[1]}\n")

fig, ax = plt.subplots(figsize=(10, 7))

# Create the violin plot
plt.violinplot(data, showmeans=True, showmedians=False)

# Add x-axis labels
plt.xticks([1, 2], ['Correct', 'Incorrect'])

# Title and labels
plt.title('Violin Plot for Correct and Incorrect Data')
plt.ylabel('Values')
plt.xlabel('Categories')

# Add horizontal lines for means
ax.hlines(y=means[0], xmin=0.5, xmax=1.5, colors='green', linestyles='solid', label=f'Mean Correct: {means[0]:.6f}')
ax.hlines(y=means[1], xmin=1.5, xmax=2.5, colors='red', linestyles='solid', label=f'Mean Incorrect: {means[1]:.6f}')

# Annotate means on the plot
plt.text(0, means[0], f'{means[0]:.6f}', ha='center', va='bottom', color='green')
plt.text(0, means[1], f'{means[1]:.6f}', ha='center', va='bottom', color='red')

# Add legend
plt.legend()

# Show plot
plt.show()
# Out:
# Mean values:
# Correct Capsule = 0.0006975052529014647
# Incorrect Capsule = 4.068738780915737e-05

# %% [markdown]
# ## Hide Irrelevant parts of the image

# %%
# Evalaute On The Range Below
startingIndex = 0
endIndex = 6
backColour = 'black'
textColour = 'white'
alphaValue = 0.75
defaultColourMap = 'turbo'
decimalPrecision = 6

totalChange = 0

# Number of images to plot
num_images = endIndex - startingIndex

# Determine the grid size for subplots (e.g., 2x2 grid for 4 images)
num_cols = 4
num_rows = (num_images + num_cols - 1) // num_cols

# Create a figure with the desired number of subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 10), facecolor=backColour)

# Flatten axes array for easy indexing
axes = axes.flatten()

with tf.Session() as sess:
    saver.restore(sess, checkpoint_path)

    for i in range(startingIndex, endIndex):
        prediction = loaded_array[i][1]
        ground_truth = loaded_array[i][2]
        featureMap = loaded_array[i][0][:, :, int(ground_truth)]

        # Apply The Threshold
        featureMap[featureMap < means[1]] = 0

        confidenceScore = loaded_array[i][3][int(ground_truth)]
        image_index = loaded_array[i][4]

        baseImage = x_test[image_index]

        # Resize the feature map to match the base image dimensions
        scale_factor = (input_dimensions[0] / featureMap.shape[0], input_dimensions[1] / featureMap.shape[1])
        resized_featureMap = zoom(featureMap, scale_factor)

        # New Prediction With Irrelevant Areas Hidden
        # Repredict
        # Mask The Irrelevent Areas With 0's, the multiplying should be good enough since matplotlib will take care of rescaling?
        overlayedImage = resized_featureMap.reshape(input_dimensions[0], input_dimensions[1],
                                                    input_dimensions[2]) * baseImage

        # Renormalize The Image So It's Between 0-1 like the model expects
        normalized_image = (overlayedImage - np.min(overlayedImage)) / (np.max(overlayedImage) - np.min(overlayedImage))

        # Run the session to get outputs
        out = sess.run([visualize_convcaps(caps_and_routing, caps_and_routing_dims, reduce), y_predictions, lengths],
                       feed_dict={
                           X: normalized_image.reshape(1, input_dimensions[0], input_dimensions[1],
                                                       input_dimensions[2]),
                           y: [y_test[image_index]]})

        prediction2 = out[1][0]  # Predicted value
        ground_truth2 = y_test[image_index]  # Actual label
        confidenceScore2 = out[2].flatten().tolist()[int(ground_truth2)]  # Confidence scores
        featureMap2 = out[0][:, :, int(ground_truth2)]

        resized_featureMap2 = zoom(featureMap2, scale_factor)

        # Plot the base image in the corresponding subplot
        axes[i - startingIndex].imshow(normalized_image, cmap='gray')

        # Overlay the resized feature map with some transparency
        axes[i - startingIndex].imshow(resized_featureMap2, cmap=defaultColourMap, alpha=alphaValue)

        # Set title for each subplot
        axes[i - startingIndex].set_title(
            f"Expected | Got         \n"
            f"{class_names[int(ground_truth2)]} |  {class_names[int(prediction2)]}\n"
            f"{confidenceScore:.{decimalPrecision}f} | {confidenceScore2:.{decimalPrecision}f}\n"
            f"Change Of: {(confidenceScore2 - confidenceScore):.{decimalPrecision}f}",
            fontsize=12, color=textColour
        )
        
        totalChange+=confidenceScore2 - confidenceScore

        #.set_title(f'Class: {class_names[int(ground_truth)]}\nConfidence Change: {confidenceScore-:.{decimalPrecision}f}', fontsize=12, color=textColour)
        axes[i - startingIndex].axis('off')

# Hide any unused subplots
for j in range(num_images, num_rows * num_cols):
    axes[j].axis('off')

# Adjust spacing between plots
#plt.subplots_adjust(hspace=0.3, wspace=0.3)  # Adjust hspace and wspace values as needed

print(f"Average Confidence Change Of: {totalChange/(endIndex-startIndex)}")

plt.tight_layout()

# Display all plots
plt.show()
# Out:
# INFO:tensorflow:Restoring parameters from C:\Users\Michael\Desktop\Model Benchmark\tensorboard\Models\CatOrDogStandard16_lr0.0001/my_capsule_network
# Average Confidence Change Of: -0.07088505228360494
